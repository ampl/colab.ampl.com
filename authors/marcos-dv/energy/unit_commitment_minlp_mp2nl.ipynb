# %% [markdown]
# # Unit Commitment MINLP with Knitro
# [![unit_commitment_minlp_mp2nl.ipynb](https://img.shields.io/badge/github-%23121011.svg?logo=github)](https://github.com/ampl/colab.ampl.com/blob/master/authors/marcos-dv/energy/unit_commitment_minlp_mp2nl.ipynb) [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ampl/colab.ampl.com/blob/master/authors/marcos-dv/energy/unit_commitment_minlp_mp2nl.ipynb) [![Open In Deepnote](https://deepnote.com/buttons/launch-in-deepnote-small.svg)](https://deepnote.com/launch?url=https://github.com/ampl/colab.ampl.com/blob/master/authors/marcos-dv/energy/unit_commitment_minlp_mp2nl.ipynb) [![Open In Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/ampl/colab.ampl.com/blob/master/authors/marcos-dv/energy/unit_commitment_minlp_mp2nl.ipynb) [![Open In Gradient](https://assets.paperspace.io/img/gradient-badge.svg)](https://console.paperspace.com/github/ampl/colab.ampl.com/blob/master/authors/marcos-dv/energy/unit_commitment_minlp_mp2nl.ipynb) [![Open In SageMaker Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/ampl/colab.ampl.com/blob/master/authors/marcos-dv/energy/unit_commitment_minlp_mp2nl.ipynb) [![Powered by AMPL](https://h.ampl.com/https://github.com/ampl/colab.ampl.com/blob/master/authors/marcos-dv/energy/unit_commitment_minlp_mp2nl.ipynb)](https://ampl.com)
#
# Description: Solving a nonlinear Unit Commitment problem with Knitro using MP features for logic and multi-objective optimization. The goal of this notebook is to show a straightforward and clear way of using nonlinear solvers for complex models with logical expressions and also hierarchical multi-objective optimization.
#
# Tags: mp, knitro, mp2nl, nonlinear, quadratic, minlp, unit-commitment, electric-power-industry, energy, multi-objective, gurobi, xpress, mp2nl
#
# Notebook author: Marcos Dominguez Velad <<marcos@ampl.com>>

# %%
# Install dependencies
# %pip install -q amplpy pandas numpy

# %%
# Google Colab & Kaggle integration
from amplpy import AMPL, ampl_notebook

ampl = ampl_notebook(
    modules=["mp2nl", "knitro", "xpress", "gurobi"],  # modules to install
    license_uuid="default",  # license to use
)  # instantiate AMPL object and register magics

# %% [markdown]
# ## The problem
#
# We are solving a version of Unit Commitment with generators with minimum and maximum outputs and ramp limits. There are linear and quadratic costs, so the problem becomes a MINLP, and we aim to minimize CO2 emissions while minimizing production costs, so it is a multi-objective problem.
#
# We will focus on the nonlinear and multi-objective part of the problem for this case. The model is written in AMPL for it to keep easy to read.
#
# Warning: this notebook uses commercial solvers, so when running on Cloud you may need a license for these solvers (Knitro, Gurobi, Xpress), or run locally.
#
# ### MINLP
#
# One of the 2 objectives is minimizing total cost, which is a nonlinear expression.
#
# * Total cost:
# $$
# \min \; \sum_{g \in \text{GEN}} \sum_{t \in \text{T}}
# \left(
# c_g^{\text{lin}} \, p_{g,t}
# + c_g^{\text{quad}} \, p_{g,t}^2
# \right)
# \;+\;
# \sum_{g \in \text{GEN}} \sum_{t \in \text{T}}
# c_g^{\text{start}} \, y_{g,t}$$
#
# Where $p_{g,t}$ is the amount of energy produced by the generator $g$ in time $t$, and $y_{g,t}$ is 1 if the generator started at period $t$ (startup cost).
#
# There are also some logical constraints to make the model clear. We have some binary variables to model easier if a generator is turned on or has just started:
#
# * Producing if and only if commited (binaries $x_{g,t}$):
# $$
# p_{g,t} > 0 \;\Longleftrightarrow\; x_{g,t} = 1
# \qquad \forall g \in \text{GEN},\; t \in \text{T}
# $$
#
# * Commited if and only if producing:
# $$
# y_{g,t} \;\Longleftrightarrow\; \big( x_{g,t} = 1 \;\land\; x_{g,t-1} = 0 \big)
# \qquad \forall g \in \text{GEN}
# $$
#
# * Amount of energy produced is either 0 or at least over a threshold (minimum input).
# $$
# p_{g,t} = 0 \;\;\text{or}\;\; p_{g,t} \ge \underline{P}_g
# \qquad \forall g \in \text{GEN},\; t \in \text{T}
# $$
#
# * Ramp limits:
#
# $$
# R_g^{\downarrow}
# \;\le\;
# \left| p_{g,t} - p_{g,t-1} \right|
# \;\le\;
# R_g^{\uparrow}
# \qquad \forall g \in \text{GEN}
# $$
#
# Solvers don't necessarily handle logical expressions, but the AMPL/MP interface takes care of reformulating efficiently these expressions.
#
# ### Multi-objective
#
# We have 2 objectives. We are going to do hierarchical optimization minimizing first the total cost minimization problem, and later the emissions, allowing a degradation of the total cost of 5%.
#
# This will be handled by suffixes for the objectives, `.objpriority` and `.objreltol`.
#
# ## MINLP Unit Commitment model

# %%
# %%writefile unit_commitment.mod
# set GENERATORS;
# set TIME ordered;
#
# param demand {TIME} >= 0;                   # Power demand at each time
# param min_output {GENERATORS} >= 0;         # Minimum power output
# param max_output {g in GENERATORS} >= min_output[g];  # Maximum power output
# param ramp_up_limit {GENERATORS} >= 0;
# param ramp_down_limit {GENERATORS} >= 0;
#
# param linear_cost {GENERATORS};             # Linear cost coefficient
# param quadratic_cost {GENERATORS} >= 0;     # Quadratic cost coefficient
# param startup_cost {GENERATORS} >= 0;       # Startup cost
#
# param emission_rate {GENERATORS} >= 0;      # Tons CO2 per MW produced
#
# var is_committed {GENERATORS, TIME} binary;       # 1 if generator is ON
# var power_generated {gen in GENERATORS, TIME} >= 0 <= max_output[gen];      # MW produced
# var is_startup {GENERATORS, TIME} binary;         # 1 if generator starts up
#
# # Meet demand in each period
# subject to Demand_Satisfaction {t in TIME}:
#     sum {gen in GENERATORS} power_generated[gen,t] >= demand[t];
#
# # Startup in first period
# subject to Startup_First {gen in GENERATORS}:
#     is_startup[gen, first(TIME)] == is_committed[gen, first(TIME)];
#
# # Startup logic in subsequent periods
# subject to Startup_Transition {gen in GENERATORS, t in TIME: ord(t) > 1}:
#     is_startup[gen,t] <==> (is_committed[gen,t] and !is_committed[gen,prev(t)]);
#
# subject to Min_Gen_If_On {gen in GENERATORS, t in TIME}:
#     (power_generated[gen,t] <= 0 && is_committed[gen,t] < 0.5)
#       or (power_generated[gen,t] >= min_output[gen] && is_committed[gen,t] >= 0.5);
#
# # Ramp-up/down limits
# subject to Ramp {gen in GENERATORS, t in TIME: ord(t) > 1}:
#     # ramp_down_limit[gen] <=
#        abs(power_generated[gen,t] - power_generated[gen,prev(t)]) <= ramp_up_limit[gen];
#
# # Objective 1: Minimize total operating + startup cost
# minimize Total_Cost:
#     sum {gen in GENERATORS, t in TIME}
#         (linear_cost[gen] * power_generated[gen,t] +
#          quadratic_cost[gen] * power_generated[gen,t]^2)
#   + sum {gen in GENERATORS, t in TIME} startup_cost[gen] * is_startup[gen,t];
#
# # Objective 2: Minimize total emissions
# minimize Total_Emissions:
#     sum {gen in GENERATORS, t in TIME} emission_rate[gen] * power_generated[gen,t];
#
# # Multi-objective support
# suffix objpriority;
# suffix objabstol;
# suffix objreltol;
# Out:
# Overwriting unit_commitment.mod

# %% [markdown]
# ## Solving the model
#
# ### Generate the problem data
#
# The AMPL model is isolated from the input data for more readability and maintainance

# %%
import pandas as pd
import numpy as np

# Unit Commitment data
generators = ["G1", "G2", "G3", "G4", "G5", "G6", "G7"]

# Generators data
generators_data = pd.DataFrame(
    {
        "min_output": [20, 30, 25, 15, 10, 40, 0],
        "max_output": [100, 120, 90, 60, 50, 150, 30],
        "ramp_up_limit": [40, 50, 30, 25, 20, 60, 10],
        "ramp_down_limit": [40, 50, 30, 25, 20, 60, 10],
        "linear_cost": [20, 16, 18, 22, 24, 14, 12],
        "quadratic_cost": [0.04, 0.05, 0.06, 0.03, 0.04, 0.036, 0.1],
        "startup_cost": [400, 300, 360, 200, 160, 600, 160],
        "emission_rate": [0.7, 0.5, 0.6, 0.4, 0.3, 0.8, 0.0],
    },
    index=generators,
)

# Generate random demand
num_time_periods = 24 * 3
time_periods = list(range(1, num_time_periods + 1))

np.random.seed(42)
base_demand = 150 + 40 * np.sin(np.linspace(0, 3 * np.pi, num_time_periods))
noise = np.random.normal(0, 10, num_time_periods)
demand = (base_demand + noise).clip(min=100).round().astype(int)

# %% [markdown]
# ### Assign the UC data

# %%
# Optimization model and data
ampl = AMPL()
ampl.read("unit_commitment.mod")

ampl.set["TIME"] = time_periods
ampl.set["GENERATORS"] = generators
ampl.param["demand"] = demand
ampl.set_data(generators_data, "GENERATORS")

# %% [markdown]
# ### Running the solver
#
# For nonlinear solvers like Knitro, we need the `mp2nl` interface to make it handle logical constraints and multi-objective. See the following example for the `knitro` solver.

# %%
# Hierarchical Multi-objective configuration
# Higher priority first
ampl.eval("let Total_Cost.objpriority := 2;")
# Set 10% degradation tolerance for total cost
ampl.eval("let Total_Cost.objreltol := 0.10;")
# Second objective (less priority)
ampl.eval("let Total_Emissions.objpriority := 1;")

SOLVER = "knitro"
# SOLVER='gurobi'
# SOLVER='xpress'

# Time limit
max_seconds = 30

if SOLVER == "knitro":
    ampl.solve(
        solver="mp2nl",
        knitro_options="numthreads=8 ms_enable=1 maxtime=" + str(max_seconds),
        verbose=True,
        mp2nl_options="solver=knitro obj:multi=2 outlev=1",
    )
else:
    ampl.solve(
        solver=SOLVER,
        mp_options="obj:multi=2 outlev=1 timelim=" + str(max_seconds),
        verbose=True,
    )
# Out:
# MP2NL 0.1:   nl:solver = knitro
#   obj:multi = 2
#   tech:outlev = 1
#
# AMPL MP initial flat model has 1512 variables (0 integer, 1008 binary);
# Objectives: 2 linear;
# Constraints:  1570 linear; 1 quadratic;
# Algebraic expressions:  497 abs;
# Logical expressions:  936 conditional (in)equalitie(s); 1433 and; 504 not; 504 or;
#
#
#
# ==============================================================================
# MULTI-OBJECTIVE MODE: starting with 2 objectives (2 combined) ...
# ==============================================================================
# ==============================================================================
#
# AMPL MP final model has 6382 variables (0 integer, 4882 binary);
# Objectives: 1 linear; 1 quadratic;
# Constraints:  6870 linear; 1 quadratic;
#
#
#
#
# MULTI-OBJECTIVE MODE: objective 1 (out of 2) ...
# ==============================================================================
#
# Artelys Knitro 15.1.0: numthreads=8
# ms_enable=1
# maxtime=30
#
# =======================================
#           Commercial License
#          Artelys Knitro 15.1.0
# =======================================
#
# Knitro changing mip_method from AUTO to 1.
# No start point provided -- Knitro computing one.
#
# concurrent_evals         0
# datacheck                0
# feastol                  1e-06
# feastol_abs              1e-06
# findiff_numthreads       1
# hessian_no_f             1
# hessopt                  1
# maxtime                  30
# ms_enable                1
# numthreads               8
# opttol                   1e-06
# opttol_abs               0.001
# Knitro changing mip_root_nlpalg from AUTO to 1.
# Knitro changing mip_node_nlpalg from AUTO to 1.
# Knitro changing mip_branchrule from AUTO to 2.
# Knitro changing mip_selectrule from AUTO to 2.
# Knitro changing mip_mir from AUTO to 2.
# Knitro changing mip_clique from AUTO to 0.
# Knitro changing mip_zerohalf from AUTO to 0.
# Knitro changing mip_liftproject from AUTO to 0.
# Knitro changing mip_knapsack from AUTO to 2.
# Knitro changing mip_gomory from AUTO to 1.
# Knitro changing mip_cut_flowcover from AUTO to 2.
# Knitro changing mip_cut_probing from AUTO to 1.
# Knitro changing mip_rounding from AUTO to 3.
# Knitro changing mip_heuristic_strategy from AUTO to 1.
# Knitro changing mip_heuristic_feaspump from AUTO to 1.
# Knitro changing mip_heuristic_misqp from AUTO to 0.
# Knitro changing mip_heuristic_mpec from AUTO to 1.
# Knitro changing mip_heuristic_diving from AUTO to 0.
# Knitro changing mip_heuristic_lns from AUTO to 0.
# Knitro changing mip_heuristic_localsearch from AUTO to 1.
# Knitro changing mip_heuristic_fixpropagate from AUTO to 1.
# Knitro changing mip_pseudoinit from AUTO to 1.
#
# Problem Characteristics                     |           Presolved
# -----------------------
# Problem type: convex MIQP
# Objective: minimize / quadratic
# Number of variables:                   6382 |                          6382
#   bounds:         lower     upper     range |     lower     upper     range
#                       0         0      3881 |         0         0      3881
#                              free     fixed |                free     fixed
#                               497      2004 |                 497      2004
#                   cont.    binary   integer |     cont.    binary   integer
#                    3005      3377         0 |      3005      3377         0
# Number of constraints:                 6870 |                          6870
#                     eq.     ineq.     range |       eq.     ineq.     range
#   linear:           504      6366         0 |       504      6366         0
#   quadratic:          0         0         0 |         0         0         0
# Number of nonzeros:
#               objective  Jacobian   Hessian | objective  Jacobian   Hessian
#   linear:          1008     15598           |      1008     15598
#   quadratic:        504         0       504 |       504         0       504
#   total:           1008     15598       504 |      1008     15598       504
#
# Knitro using Branch and Bound method with 8 threads.
#
# Initial points
# --------------
# No initial point provided for the root node relaxation.
# No primal point provided for the MIP.
#
# Coefficient range:
#   linear objective:          [1e+01, 6e+02] |                [2e+00, 1e+02]
#   linear constraints:        [1e+00, 2e+02] |                [7e-01, 1e+02]
#   quadratic objective:       [3e-02, 1e-01] |                [5e-03, 2e-02]
#   quadratic constraints:     [0e+00, 0e+00] |                [0e+00, 0e+00]
#   variable bounds:           [1e+00, 2e+02] |                [1e+00, 2e+02]
#   constraint bounds:         [1e+00, 2e+02] |                [1e+00, 2e+02]
#
# Root node relaxation
# --------------------
#
#  Iter      Objective      Feasibility        Optimality       Time
#                              error              error        (secs)
#  ----      ---------      -----------        ----------      ------
#     1        295121.          8.38079           36.8332       0.096
#     2        270117.          1.12326           13.9067       0.103
#     3        283808.         0.356931           13.9067       0.108
#     4        278669.      2.90422e-02           5.65182       0.114
#     5        242878.      3.29207e-03           3.09336       0.120
#     6        215855.      5.41054e-04           1.60276       0.126
#     7        199904.      6.16854e-05          0.601843       0.132
#     8        193907.      2.99138e-06          0.107911       0.138
#     9        193297.      1.11238e-06       6.40843e-02       0.144
#    10        193086.      5.05880e-07       4.59638e-02       0.149
#    11        192905.      1.64579e-07       5.32820e-02       0.154
#    12        192774.      3.77584e-09       7.49303e-03       0.160
#    13        192769.      4.47140e-09       5.00629e-03       0.165
#    14        192753.      9.30451e-10       1.57348e-03       0.172
#    15        192746.      9.84950e-09       1.30336e-04       0.177
#    16        192746.      2.00813e-09       9.10167e-06       0.183
#    17        192746.      2.00813e-09       9.10167e-06       0.193
#    18        192746.      2.00813e-09       9.10167e-06       0.210
#
# Root node cutting planes
# ------------------------
#
#  Iter     Cuts      Best solution   Best bound      Gap       Time
#                         value         value                  (secs)
#  ----     ----      -------------   ----------      ---      ------
#     0        0       955028.           192746.     79.82%     0.343
#     1     2309       955028.           193014.     79.79%     0.587
#
# Tree search
# -----------
#
#        Nodes        Best solution   Best bound      Gap       Time
#    Expl  |  Unexpl      value         value                  (secs)
#    ---------------  -------------   ----------      ---      ------
#       1       2      955028.           193019.     79.79%     0.738
#       1       2      195583.   FP      193019.      1.31%     0.832
#       1       2      194935. MPEC      193019.      0.98%     1.257
#      10      11      194935.           193215.      0.88%    21.875
#      20      21      194935.           193303.      0.84%    23.629
#      30      31      194935.           193308.      0.83%    25.644
#      40      41      194935.           193387.      0.79%    27.350
#      50      51      194935.           193392.      0.79%    29.096
#      56      55      194935.           193397.      0.79%    30.020
#
# EXIT: Time limit reached. Integer feasible point found.
#
# Final Statistics for MIP
# ------------------------
# Final objective value               =  1.94934762310298975e+05
# Final bound value                   =  1.93396600792713056e+05
# Final optimality gap (abs / rel)    =  1538.16 / 7.89065e-03 (0.79%)
# # of root cutting plane rounds      =  2
# # of restarts                       =  0
# # of nodes processed                =  56 (9.798s)
# # of strong branching evaluations   =  0 (0.000s)
# # of function evaluations           =  0 (0.000s)
# # of gradient evaluations           =  0 (0.000s)
# # of hessian evaluations            =  0 (0.000s)
# # of hessian-vector evaluations     =  0
# # of subproblems processed          =  273 (28.416s)
# Total program time (secs)           =  30.02016 (219.624 CPU time)
# Time spent in evaluations (secs)    =  0.00000
#
# Cuts statistics (gen / add)
# ---------------------------
# Knapsack cuts                       =  44 / 15
# Mixed-integer rounding cuts         =  0 / 0
# Gomory cuts                         =  0 / 0
# Flow-cover cuts                     =  0 / 0
# Probing cuts                        =  20676 / 3476
#
# Heuristics statistics (calls / successes / time)
# ------------------------------------------------
# Feasibility pump                    =  2 / 1 / 12.666s
# Rounding heuristic                  =  3 / 0 / 0.036s
# MPEC heuristic                      =  2 / 1 / 6.502s
# Local search heuristic              =  6 / 1 / 0.118s
# Fix-and-propagate heuristics        =  0 / 0 / 0.000s
#
# ===========================================================================
#
#
#
# MULTI-OBJECTIVE MODE: objective 2 (out of 2) ...
# ==============================================================================
#
# Artelys Knitro 15.1.0: numthreads=8
# ms_enable=1
# maxtime=30
#
# =======================================
#           Commercial License
#          Artelys Knitro 15.1.0
# =======================================
#
# Knitro changing mip_method from AUTO to 1.
# concurrent_evals         0
# datacheck                0
# feastol                  1e-06
# feastol_abs              1e-06
# findiff_numthreads       1
# hessian_no_f             1
# hessopt                  1
# maxtime                  30
# ms_enable                1
# numthreads               8
# opttol                   1e-06
# opttol_abs               0.001
# Knitro changing mip_root_nlpalg from AUTO to 1.
# Knitro changing mip_node_nlpalg from AUTO to 1.
# Knitro changing mip_branchrule from AUTO to 2.
# Knitro changing mip_selectrule from AUTO to 2.
# Knitro changing mip_mir from AUTO to 2.
# Knitro changing mip_clique from AUTO to 0.
# Knitro changing mip_zerohalf from AUTO to 0.
# Knitro changing mip_liftproject from AUTO to 0.
# Knitro changing mip_knapsack from AUTO to 2.
# Knitro changing mip_gomory from AUTO to 1.
# Knitro changing mip_cut_flowcover from AUTO to 2.
# Knitro changing mip_cut_probing from AUTO to 1.
# Knitro changing mip_rounding from AUTO to 3.
# Knitro changing mip_heuristic_strategy from AUTO to 1.
# Knitro changing mip_heuristic_feaspump from AUTO to 1.
# Knitro changing mip_heuristic_misqp from AUTO to 0.
# Knitro changing mip_heuristic_mpec from AUTO to 1.
# Knitro changing mip_heuristic_diving from AUTO to 0.
# Knitro changing mip_heuristic_lns from AUTO to 0.
# Knitro changing mip_heuristic_localsearch from AUTO to 1.
# Knitro changing mip_heuristic_fixpropagate from AUTO to 1.
# Knitro changing mip_pseudoinit from AUTO to 1.
#
# Problem Characteristics                     |           Presolved
# -----------------------
# Problem type: convex MIQCQP
# Objective: minimize / linear
# Number of variables:                   6382 |                          6382
#   bounds:         lower     upper     range |     lower     upper     range
#                       0         0      3881 |         0         0      3881
#                              free     fixed |                free     fixed
#                               497      2004 |                 497      2004
#                   cont.    binary   integer |     cont.    binary   integer
#                    3005      3377         0 |      3005      3377         0
# Number of constraints:                 6871 |                          6871
#                     eq.     ineq.     range |       eq.     ineq.     range
#   linear:           504      6366         0 |       504      6366         0
#   quadratic:          0         1         0 |         0         1         0
# Number of nonzeros:
#               objective  Jacobian   Hessian | objective  Jacobian   Hessian
#   linear:           432     16606           |       432     16606
#   quadratic:          0       504       504 |         0       504       504
#   total:            432     16606       504 |       432     16606       504
#
# Knitro using Branch and Bound method with 8 threads.
#
# Initial points
# --------------
# Read root node initial point:
#     Objective value:    6.459585e+03
#     Feasibility error:  1.248592e-10
#     Feasible:           yes
# Read MIP primal point:
#     Objective value:    6.459585e+03
#     Feasibility error:  1.248592e-10
#     Feasible:           yes
#
# Coefficient range:
#   linear objective:          [3e-01, 8e-01] |                [3e-01, 8e-01]
#   linear constraints:        [1e+00, 6e+02] |                [7e-01, 1e+02]
#   quadratic objective:       [0e+00, 0e+00] |                [0e+00, 0e+00]
#   quadratic constraints:     [3e-02, 1e-01] |                [5e-03, 2e-02]
#   variable bounds:           [1e+00, 2e+02] |                [1e+00, 2e+02]
#   constraint bounds:         [1e+00, 2e+05] |                [1e+00, 4e+04]
#
# Root node relaxation
# --------------------
#
#  Iter      Objective      Feasibility        Optimality       Time
#                              error              error        (secs)
#  ----      ---------      -----------        ----------      ------
#     1        6419.24      7.98604e-02          0.562389       0.116
#     2        6271.03      6.20364e-02          0.499796       0.123
#     3        6064.87      3.23383e-02          0.491018       0.131
#     4        5524.44      4.53620e-03          0.466880       0.137
#     5        5384.46          80.9117          0.456584       0.143
#     6        5039.88      8.32555e-04          0.478927       0.149
#     7        4790.04      1.08125e-04          0.282792       0.156
#     8        4670.37      2.90406e-06          0.275950       0.164
#     9        4661.60      1.24577e-06          0.257099       0.172
#    10        4657.66      4.80102e-07          0.139040       0.185
#    11        4655.43      2.07452e-07       7.96957e-02       0.201
#    12        4654.37      7.75968e-08       4.03738e-02       0.207
#    13        4652.88      5.68305e-10       6.66580e-04       0.216
#    14        4652.79      4.45899e-11       3.44036e-04       0.224
#    15        4652.78      1.16803e-04       5.80662e-06       0.235
#    16        4652.78      1.20639e-05       5.99733e-07       0.244
#    17        4652.78      5.13304e-07       1.03063e-07       0.254
#    18        4652.78      5.13304e-07       1.03063e-07       0.310
#
# Root node cutting planes
# ------------------------
#
#  Iter     Cuts      Best solution   Best bound      Gap       Time
#                         value         value                  (secs)
#  ----     ----      -------------   ----------      ---      ------
#     0        0       6459.59           4652.78     27.97%     0.468
#
# Tree search
# -----------
#
#        Nodes        Best solution   Best bound      Gap       Time
#    Expl  |  Unexpl      value         value                  (secs)
#    ---------------  -------------   ----------      ---      ------
#       1       2      6459.59           4653.70     27.96%     0.744
#       1       2      6459.59           4653.70     27.96%    33.446
#
# EXIT: Time limit reached. Integer feasible point found.
#
# Final Statistics for MIP
# ------------------------
# Final objective value               =  6.45958538545912870e+03
# Final bound value                   =  4.65369982632815572e+03
# Final optimality gap (abs / rel)    =  1805.89 / 0.279567 (27.96%)
# # of root cutting plane rounds      =  2
# # of restarts                       =  0
# # of nodes processed                =  1 (0.367s)
# # of strong branching evaluations   =  0 (0.000s)
# # of function evaluations           =  0 (0.000s)
# # of gradient evaluations           =  0 (0.000s)
# # of hessian evaluations            =  0 (0.000s)
# # of hessian-vector evaluations     =  0
# # of subproblems processed          =  405 (31.921s)
# Total program time (secs)           =  33.44618 (254.325 CPU time)
# Time spent in evaluations (secs)    =  0.00000
#
# Cuts statistics (gen / add)
# ---------------------------
# Knapsack cuts                       =  3 / 1
# Mixed-integer rounding cuts         =  0 / 0
# Gomory cuts                         =  0 / 0
# Flow-cover cuts                     =  0 / 0
# Probing cuts                        =  20625 / 3448
#
# Heuristics statistics (calls / successes / time)
# ------------------------------------------------
# Feasibility pump                    =  2 / 0 / 27.104s
# Rounding heuristic                  =  2 / 0 / 0.007s
# MPEC heuristic                      =  1 / 0 / 5.571s
# Local search heuristic              =  5 / 0 / 0.121s
# Fix-and-propagate heuristics        =  0 / 0 / 0.000s
#
# ===========================================================================
#
#
#
# ==============================================================================
# MULTI-OBJECTIVE MODE: done.
#
# MP2NL 0.1: Knitro 15.1.0: Time limit reached. Current point is feasible.
# objective 6459.585385; optimality gap 1.81e+03
# 1 nodes; 405 subproblem solves
#
# ------------ WARNINGS ------------
# WARNING.  2 case(s) of "Tolerance violations". One of them:
#   Type                         MaxAbs [Name]   MaxRel [Name]
# * aux var bounds               1E+00           1E+00
# *: Using the solver's aux variable values.
# Documentation: mp.ampl.com/modeling-tools.html#automatic-solution-check.
#
# suffix numiters OUT;
# suffix opterror OUT;
# suffix relaxbnd OUT;
# suffix feaserror OUT;
# suffix incumbent OUT;
# suffix numfcevals OUT;
# Objective = Total_Cost

# %%
print("Solution status:", ampl.solve_result, " solve code:", ampl.solve_result_num)

print("=== Objective Values ===")
total_cost = ampl.obj["Total_Cost"].value()
total_emissions = ampl.obj["Total_Emissions"].value()

print(f"Total cost: {total_cost:.2f}$")
print(f"Total emissions: {total_emissions:.2f} tons CO₂")

is_committed = ampl.get_data("is_committed").to_pandas()
display(is_committed.unstack().T)
produce = ampl.get_data("power_generated").to_pandas()
display(produce.unstack().T)
startup = ampl.get_data("is_startup").to_pandas()
display(startup.unstack().T)
# Out:
# Solution status: limit  solve code: 401
# === Objective Values ===
# Total cost: 194934.76$
# Total emissions: 6459.59 tons CO₂
# index0                         G1            G2            G3            G4  \
#              index1
# is_committed 1       1.658580e-09  1.000000e+00  1.699235e-09  1.707496e-09
#              2       1.882496e-09  1.000000e+00  1.911383e-09  1.878950e-09
#              3       1.955569e-09  1.000000e+00  1.973319e-09  1.883757e-09
#              4       1.986832e-09  1.000000e+00  1.973438e-09  1.888823e-09
#              5       2.026457e-09  1.000000e+00  2.011623e-09  1.909901e-09
# ...                           ...           ...           ...           ...
#              68      2.008324e-09  1.000000e+00  2.012490e-09  1.881302e-09
#              69      2.068006e-09  1.000000e+00  2.086111e-09  1.898399e-09
#              70      2.277060e-09  7.329301e-09  2.352734e-09  2.003154e-09
#              71      2.337372e-09  5.618569e-09  2.425224e-09  2.045661e-09
#              72      2.247044e-09  2.153266e-09  2.310726e-09  1.873226e-09
#
# index0                         G5   G6   G7
#              index1
# is_committed 1       1.648817e-09  1.0  1.0
#              2       1.873226e-09  1.0  1.0
#              3       1.905313e-09  1.0  1.0
#              4       1.909355e-09  1.0  1.0
#              5       1.908176e-09  1.0  1.0
# ...                           ...  ...  ...
#              68      1.905900e-09  1.0  1.0
#              69      1.912496e-09  1.0  1.0
#              70      1.966267e-09  1.0  1.0
#              71      1.995873e-09  1.0  1.0
#              72      1.861472e-09  1.0  1.0
#
# [72 rows x 7 columns]
# index0                            G1            G2            G3  \
#                 index1
# power_generated 1       1.135058e-07  4.069773e+01  1.115721e-07
#                 2       1.272453e-07  4.027913e+01  1.247565e-07
#                 3       1.387907e-07  4.572093e+01  1.334522e-07
#                 4       1.472054e-07  5.158140e+01  1.370520e-07
#                 5       1.421771e-07  4.613954e+01  1.399928e-07
# ...                              ...           ...           ...
#                 68      1.444286e-07  5.116280e+01  1.415811e-07
#                 69      1.472153e-07  4.655810e+01  1.471091e-07
#                 70      1.677060e-07  8.113498e-07  1.656043e-07
#                 71      1.790038e-07  6.208047e-07  1.732424e-07
#                 72      1.753715e-07  2.151713e-07  1.682105e-07
#
# index0                            G4            G5          G6         G7
#                 index1
# power_generated 1       6.957816e-08  5.910053e-08   84.302272  29.999994
#                 2       7.635133e-08  6.241822e-08   83.720875  29.999994
#                 3       8.062688e-08  6.461577e-08   91.279069  29.999998
#                 4       8.109108e-08  6.495747e-08   99.418600  29.999998
#                 5       7.939512e-08  6.470705e-08   91.860461  29.999998
# ...                              ...           ...         ...        ...
#                 68      8.053366e-08  6.460855e-08   98.837203  29.999998
#                 69      8.091123e-08  6.462826e-08   92.441904  29.999998
#                 70      8.538225e-08  6.835195e-08  124.000000  29.999999
#                 71      8.870643e-08  7.048876e-08  129.000000  29.999999
#                 72      8.399062e-08  6.624555e-08  135.000000  29.999999
#
# [72 rows x 7 columns]
# index0                       G1            G2            G3            G4  \
#            index1
# is_startup 1       1.693351e-09  1.000000e+00  1.733298e-09  1.708273e-09
#            2       1.123651e-09  1.136842e-09  1.128229e-09  1.132585e-09
#            3       1.103249e-09  1.035702e-09  1.099492e-09  1.115316e-09
#            4       1.112066e-09  1.139432e-09  1.103355e-09  1.111419e-09
#            5       1.116111e-09  1.019368e-09  1.102813e-09  1.111399e-09
# ...                         ...           ...           ...           ...
#            68      1.121666e-09  9.974424e-10  1.117045e-09  1.111238e-09
#            69      1.148105e-09  9.868299e-10  1.161804e-09  1.116198e-09
#            70      1.347596e-09  8.151719e-10  1.389973e-09  1.153317e-09
#            71      1.177983e-09  1.526067e-09  1.207672e-09  1.141711e-09
#            72      1.110050e-09  1.094846e-09  1.122740e-09  1.073342e-09
#
# index0                       G5            G6            G7
#            index1
# is_startup 1       1.705907e-09  1.000000e+00  1.000000e+00
#            2       1.136004e-09  9.168967e-10  9.047278e-10
#            3       1.119617e-09  9.672345e-10  1.010287e-09
#            4       1.117332e-09  9.782011e-10  1.019485e-09
#            5       1.116587e-09  9.763291e-10  1.020007e-09
# ...                         ...           ...           ...
#            68      1.115616e-09  9.831599e-10  1.020303e-09
#            69      1.118866e-09  9.791771e-10  1.020684e-09
#            70      1.141615e-09  9.766101e-10  1.027344e-09
#            71      1.136877e-09  9.798749e-10  9.950114e-10
#            72      1.072921e-09  9.925497e-10  1.016358e-09
#
# [72 rows x 7 columns]

# %% [markdown]
# - More documentation of the [AMPL/MP interface](https://mp.ampl.com/index.html) (in particular, [MP2NL](https://mp.ampl.com/modeling-tools.html#meta-driver-mp2nl)).
# - More [energy examples](https://colab.ampl.com/tags/electric-power-industry.html).

# %%
# More evaluations

ampl.eval('display _obj;')
ampl.eval('display _varname, _var.slack;');
ampl.eval('display _conname, _con.slack;');
ampl.eval('display _logconname, _logcon.val;');
# Out:
# _obj [*] :=
# 1  194935
# 2    6459.59
# ;
#
# :               _varname             _var.slack     :=
# 1      "is_committed['G1',1]"        1.65858e-09
# 2      "is_committed['G1',2]"        1.8825e-09
# 3      "is_committed['G1',3]"        1.95557e-09
# 4      "is_committed['G1',4]"        1.98683e-09
# 5      "is_committed['G1',5]"        2.02646e-09
# 6      "is_committed['G1',6]"        2.00607e-09
# 7      "is_committed['G1',7]"        2.01118e-09
# 8      "is_committed['G1',8]"        1.97456e-09
# 9      "is_committed['G1',9]"        1.93403e-09
# 10     "is_committed['G1',10]"       1.9599e-09
# 11     "is_committed['G1',11]"       1.9263e-09
# 12     "is_committed['G1',12]"       1.9263e-09
# 13     "is_committed['G1',13]"       1.96628e-09
# 14     "is_committed['G1',14]"       1.99733e-09
# 15     "is_committed['G1',15]"       1.97244e-09
# 16     "is_committed['G1',16]"       1.95209e-09
# 17     "is_committed['G1',17]"       2.00806e-09
# 18     "is_committed['G1',18]"       1.95877e-09
# 19     "is_committed['G1',19]"       2.00661e-09
# 20     "is_committed['G1',20]"       2.0058e-09
# 21     "is_committed['G1',21]"       1.96299e-09
# 22     "is_committed['G1',22]"       1.9688e-09
# 23     "is_committed['G1',23]"       1.95472e-09
# 24     "is_committed['G1',24]"       1.92682e-09
# 25     "is_committed['G1',25]"       1.91075e-09
# 26     "is_committed['G1',26]"       1.90176e-09
# 27     "is_committed['G1',27]"       1.89491e-09
# 28     "is_committed['G1',28]"       1.89935e-09
# 29     "is_committed['G1',29]"       1.92115e-09
# 30     "is_committed['G1',30]"       1.92194e-09
# 31     "is_committed['G1',31]"       1.91973e-09
# 32     "is_committed['G1',32]"       1.90595e-09
# 33     "is_committed['G1',33]"       1.91856e-09
# 34     "is_committed['G1',34]"       1.92454e-09
# 35     "is_committed['G1',35]"       1.91981e-09
# 36     "is_committed['G1',36]"       1.9258e-09
# 37     "is_committed['G1',37]"       1.92125e-09
# 38     "is_committed['G1',38]"       1.92405e-09
# 39     "is_committed['G1',39]"       1.92387e-09
# 40     "is_committed['G1',40]"       1.91635e-09
# 41     "is_committed['G1',41]"       1.8974e-09
# 42     "is_committed['G1',42]"       1.92139e-09
# 43     "is_committed['G1',43]"       1.92205e-09
# 44     "is_committed['G1',44]"       1.89795e-09
# 45     "is_committed['G1',45]"       1.91884e-09
# 46     "is_committed['G1',46]"       1.91042e-09
# 47     "is_committed['G1',47]"       1.91349e-09
# 48     "is_committed['G1',48]"       1.93363e-09
# 49     "is_committed['G1',49]"       1.94872e-09
# 50     "is_committed['G1',50]"       1.93833e-09
# 51     "is_committed['G1',51]"       1.80619e-09
# 52     "is_committed['G1',52]"       1.93303e-09
# 53     "is_committed['G1',53]"       1.97386e-09
# 54     "is_committed['G1',54]"       1.98259e-09
# 55     "is_committed['G1',55]"       1.96022e-09
# 56     "is_committed['G1',56]"       1.97184e-09
# 57     "is_committed['G1',57]"       1.96226e-09
# 58     "is_committed['G1',58]"       1.95826e-09
# 59     "is_committed['G1',59]"       1.96381e-09
# 60     "is_committed['G1',60]"       1.95947e-09
# 61     "is_committed['G1',61]"       1.95552e-09
# 62     "is_committed['G1',62]"       1.95994e-09
# 63     "is_committed['G1',63]"       1.96318e-09
# 64     "is_committed['G1',64]"       1.95697e-09
# 65     "is_committed['G1',65]"       1.93815e-09
# 66     "is_committed['G1',66]"       1.96971e-09
# 67     "is_committed['G1',67]"       1.97581e-09
# 68     "is_committed['G1',68]"       2.00832e-09
# 69     "is_committed['G1',69]"       2.06801e-09
# 70     "is_committed['G1',70]"       2.27706e-09
# 71     "is_committed['G1',71]"       2.33737e-09
# 72     "is_committed['G1',72]"       2.24704e-09
# 73     "is_committed['G2',1]"        1.62384e-09
# 74     "is_committed['G2',2]"        1.70682e-09
# 75     "is_committed['G2',3]"        1.78417e-09
# 76     "is_committed['G2',4]"        1.59647e-09
# 77     "is_committed['G2',5]"        1.55231e-09
# 78     "is_committed['G2',6]"        1.51784e-09
# 79     "is_committed['G2',7]"        1.50509e-09
# 80     "is_committed['G2',8]"        1.53353e-09
# 81     "is_committed['G2',9]"        1.51386e-09
# 82     "is_committed['G2',10]"       1.53746e-09
# 83     "is_committed['G2',11]"       1.5375e-09
# 84     "is_committed['G2',12]"       1.5359e-09
# 85     "is_committed['G2',13]"       1.51181e-09
# 86     "is_committed['G2',14]"       1.53759e-09
# 87     "is_committed['G2',15]"       1.57432e-09
# 88     "is_committed['G2',16]"       1.53994e-09
# 89     "is_committed['G2',17]"       1.53787e-09
# 90     "is_committed['G2',18]"       1.54978e-09
# 91     "is_committed['G2',19]"       1.55314e-09
# 92     "is_committed['G2',20]"       1.57523e-09
# 93     "is_committed['G2',21]"       1.5451e-09
# 94     "is_committed['G2',22]"       1.51502e-09
# 95     "is_committed['G2',23]"       1.55114e-09
# 96     "is_committed['G2',24]"       1.61452e-09
# 97     "is_committed['G2',25]"       1.55662e-09
# 98     "is_committed['G2',26]"       1.59074e-09
# 99     "is_committed['G2',27]"       1.57732e-09
# 100    "is_committed['G2',28]"       1.53846e-09
# 101    "is_committed['G2',29]"       1.55676e-09
# 102    "is_committed['G2',30]"       1.51668e-09
# 103    "is_committed['G2',31]"       1.50759e-09
# 104    "is_committed['G2',32]"       1.51195e-09
# 105    "is_committed['G2',33]"       1.5793e-09
# 106    "is_committed['G2',34]"       1.50055e-09
# 107    "is_committed['G2',35]"       1.58587e-09
# 108    "is_committed['G2',36]"       1.56847e-09
# 109    "is_committed['G2',37]"       1.55215e-09
# 110    "is_committed['G2',38]"       1.56288e-09
# 111    "is_committed['G2',39]"       1.48954e-09
# 112    "is_committed['G2',40]"       1.52383e-09
# 113    "is_committed['G2',41]"       1.51698e-09
# 114    "is_committed['G2',42]"       1.55346e-09
# 115    "is_committed['G2',43]"       1.55241e-09
# 116    "is_committed['G2',44]"       1.53022e-09
# 117    "is_committed['G2',45]"       1.53976e-09
# 118    "is_committed['G2',46]"       1.58299e-09
# 119    "is_committed['G2',47]"       1.57439e-09
# 120    "is_committed['G2',48]"       1.52961e-09
# 121    "is_committed['G2',49]"       1.55069e-09
# 122    "is_committed['G2',50]"       1.5779e-09
# 123    "is_committed['G2',51]"       1.55237e-09
# 124    "is_committed['G2',52]"       1.56121e-09
# 125    "is_committed['G2',53]"       1.57316e-09
# 126    "is_committed['G2',54]"       1.50096e-09
# 127    "is_committed['G2',55]"       1.54773e-09
# 128    "is_committed['G2',56]"       1.55133e-09
# 129    "is_committed['G2',57]"       1.53804e-09
# 130    "is_committed['G2',58]"       1.54025e-09
# 131    "is_committed['G2',59]"       1.57918e-09
# 132    "is_committed['G2',60]"       1.52172e-09
# 133    "is_committed['G2',61]"       1.54017e-09
# 134    "is_committed['G2',62]"       1.57761e-09
# 135    "is_committed['G2',63]"       1.55769e-09
# 136    "is_committed['G2',64]"       1.58126e-09
# 137    "is_committed['G2',65]"       1.58648e-09
# 138    "is_committed['G2',66]"       1.58143e-09
# 139    "is_committed['G2',67]"       1.5354e-09
# 140    "is_committed['G2',68]"       1.49133e-09
# 141    "is_committed['G2',69]"       1.61442e-09
# 142    "is_committed['G2',70]"       7.3293e-09
# 143    "is_committed['G2',71]"       5.61857e-09
# 144    "is_committed['G2',72]"       2.15327e-09
# 145    "is_committed['G3',1]"        1.69924e-09
# 146    "is_committed['G3',2]"        1.91138e-09
# 147    "is_committed['G3',3]"        1.97332e-09
# 148    "is_committed['G3',4]"        1.97344e-09
# 149    "is_committed['G3',5]"        2.01162e-09
# 150    "is_committed['G3',6]"        1.98538e-09
# 151    "is_committed['G3',7]"        1.97539e-09
# 152    "is_committed['G3',8]"        1.97248e-09
# 153    "is_committed['G3',9]"        1.94905e-09
# 154    "is_committed['G3',10]"       1.94604e-09
# 155    "is_committed['G3',11]"       1.90463e-09
# 156    "is_committed['G3',12]"       1.93191e-09
# 157    "is_committed['G3',13]"       1.95039e-09
# 158    "is_committed['G3',14]"       1.98864e-09
# 159    "is_committed['G3',15]"       1.95163e-09
# 160    "is_committed['G3',16]"       1.98604e-09
# 161    "is_committed['G3',17]"       1.9457e-09
# 162    "is_committed['G3',18]"       1.92564e-09
# 163    "is_committed['G3',19]"       1.98102e-09
# 164    "is_committed['G3',20]"       1.98921e-09
# 165    "is_committed['G3',21]"       1.97796e-09
# 166    "is_committed['G3',22]"       1.93782e-09
# 167    "is_committed['G3',23]"       1.92591e-09
# 168    "is_committed['G3',24]"       1.97824e-09
# 169    "is_committed['G3',25]"       1.96926e-09
# 170    "is_committed['G3',26]"       1.96307e-09
# 171    "is_committed['G3',27]"       1.95344e-09
# 172    "is_committed['G3',28]"       1.95109e-09
# 173    "is_committed['G3',29]"       1.9747e-09
# 174    "is_committed['G3',30]"       1.97416e-09
# 175    "is_committed['G3',31]"       1.9708e-09
# 176    "is_committed['G3',32]"       1.95189e-09
# 177    "is_committed['G3',33]"       1.96882e-09
# 178    "is_committed['G3',34]"       1.97518e-09
# 179    "is_committed['G3',35]"       1.96902e-09
# 180    "is_committed['G3',36]"       1.97601e-09
# 181    "is_committed['G3',37]"       1.97058e-09
# 182    "is_committed['G3',38]"       1.97395e-09
# 183    "is_committed['G3',39]"       1.97445e-09
# 184    "is_committed['G3',40]"       1.9696e-09
# 185    "is_committed['G3',41]"       1.97868e-09
# 186    "is_committed['G3',42]"       1.97749e-09
# 187    "is_committed['G3',43]"       1.97646e-09
# 188    "is_committed['G3',44]"       1.95177e-09
# 189    "is_committed['G3',45]"       1.97274e-09
# 190    "is_committed['G3',46]"       1.96491e-09
# 191    "is_committed['G3',47]"       1.96545e-09
# 192    "is_committed['G3',48]"       1.94656e-09
# 193    "is_committed['G3',49]"       1.95607e-09
# 194    "is_committed['G3',50]"       1.96948e-09
# 195    "is_committed['G3',51]"       1.92982e-09
# 196    "is_committed['G3',52]"       1.95428e-09
# 197    "is_committed['G3',53]"       1.98266e-09
# 198    "is_committed['G3',54]"       1.94812e-09
# 199    "is_committed['G3',55]"       1.95202e-09
# 200    "is_committed['G3',56]"       1.92841e-09
# 201    "is_committed['G3',57]"       1.96905e-09
# 202    "is_committed['G3',58]"       1.93626e-09
# 203    "is_committed['G3',59]"       1.93058e-09
# 204    "is_committed['G3',60]"       1.96276e-09
# 205    "is_committed['G3',61]"       1.93807e-09
# 206    "is_committed['G3',62]"       1.94018e-09
# 207    "is_committed['G3',63]"       1.97776e-09
# 208    "is_committed['G3',64]"       1.93792e-09
# 209    "is_committed['G3',65]"       1.94928e-09
# 210    "is_committed['G3',66]"       1.98384e-09
# 211    "is_committed['G3',67]"       1.97531e-09
# 212    "is_committed['G3',68]"       2.01249e-09
# 213    "is_committed['G3',69]"       2.08611e-09
# 214    "is_committed['G3',70]"       2.35273e-09
# 215    "is_committed['G3',71]"       2.42522e-09
# 216    "is_committed['G3',72]"       2.31073e-09
# 217    "is_committed['G4',1]"        1.7075e-09
# 218    "is_committed['G4',2]"        1.87895e-09
# 219    "is_committed['G4',3]"        1.88376e-09
# 220    "is_committed['G4',4]"        1.88882e-09
# 221    "is_committed['G4',5]"        1.9099e-09
# 222    "is_committed['G4',6]"        1.87348e-09
# 223    "is_committed['G4',7]"        1.79317e-09
# 224    "is_committed['G4',8]"        1.79863e-09
# 225    "is_committed['G4',9]"        1.76892e-09
# 226    "is_committed['G4',10]"       1.76774e-09
# 227    "is_committed['G4',11]"       1.76773e-09
# 228    "is_committed['G4',12]"       1.76707e-09
# 229    "is_committed['G4',13]"       1.7754e-09
# 230    "is_committed['G4',14]"       1.89327e-09
# 231    "is_committed['G4',15]"       1.8774e-09
# 232    "is_committed['G4',16]"       1.87626e-09
# 233    "is_committed['G4',17]"       1.88049e-09
# 234    "is_committed['G4',18]"       1.88469e-09
# 235    "is_committed['G4',19]"       1.9129e-09
# 236    "is_committed['G4',20]"       1.91281e-09
# 237    "is_committed['G4',21]"       1.88593e-09
# 238    "is_committed['G4',22]"       1.91636e-09
# 239    "is_committed['G4',23]"       1.91777e-09
# 240    "is_committed['G4',24]"       1.9167e-09
# 241    "is_committed['G4',25]"       1.91512e-09
# 242    "is_committed['G4',26]"       1.91453e-09
# 243    "is_committed['G4',27]"       1.91646e-09
# 244    "is_committed['G4',28]"       1.91489e-09
# 245    "is_committed['G4',29]"       1.91276e-09
# 246    "is_committed['G4',30]"       1.91182e-09
# 247    "is_committed['G4',31]"       1.91213e-09
# 248    "is_committed['G4',32]"       1.91545e-09
# 249    "is_committed['G4',33]"       1.91145e-09
# 250    "is_committed['G4',34]"       1.91691e-09
# 251    "is_committed['G4',35]"       1.9103e-09
# 252    "is_committed['G4',36]"       1.918e-09
# 253    "is_committed['G4',37]"       1.91234e-09
# 254    "is_committed['G4',38]"       1.91715e-09
# 255    "is_committed['G4',39]"       1.9174e-09
# 256    "is_committed['G4',40]"       1.91007e-09
# 257    "is_committed['G4',41]"       1.91328e-09
# 258    "is_committed['G4',42]"       1.91269e-09
# 259    "is_committed['G4',43]"       1.91311e-09
# 260    "is_committed['G4',44]"       1.91443e-09
# 261    "is_committed['G4',45]"       1.91312e-09
# 262    "is_committed['G4',46]"       1.91976e-09
# 263    "is_committed['G4',47]"       1.91666e-09
# 264    "is_committed['G4',48]"       1.9172e-09
# 265    "is_committed['G4',49]"       1.91812e-09
# 266    "is_committed['G4',50]"       1.91907e-09
# 267    "is_committed['G4',51]"       1.91309e-09
# 268    "is_committed['G4',52]"       1.91464e-09
# 269    "is_committed['G4',53]"       1.91269e-09
# 270    "is_committed['G4',54]"       1.87949e-09
# 271    "is_committed['G4',55]"       1.87962e-09
# 272    "is_committed['G4',56]"       1.90646e-09
# 273    "is_committed['G4',57]"       1.87854e-09
# 274    "is_committed['G4',58]"       1.8782e-09
# 275    "is_committed['G4',59]"       1.90634e-09
# 276    "is_committed['G4',60]"       1.88068e-09
# 277    "is_committed['G4',61]"       1.87603e-09
# 278    "is_committed['G4',62]"       1.87506e-09
# 279    "is_committed['G4',63]"       1.87524e-09
# 280    "is_committed['G4',64]"       1.87562e-09
# 281    "is_committed['G4',65]"       1.87756e-09
# 282    "is_committed['G4',66]"       1.90629e-09
# 283    "is_committed['G4',67]"       1.8791e-09
# 284    "is_committed['G4',68]"       1.8813e-09
# 285    "is_committed['G4',69]"       1.8984e-09
# 286    "is_committed['G4',70]"       2.00315e-09
# 287    "is_committed['G4',71]"       2.04566e-09
# 288    "is_committed['G4',72]"       1.87323e-09
# 289    "is_committed['G5',1]"        1.64882e-09
# 290    "is_committed['G5',2]"        1.87323e-09
# 291    "is_committed['G5',3]"        1.90531e-09
# 292    "is_committed['G5',4]"        1.90935e-09
# 293    "is_committed['G5',5]"        1.90818e-09
# 294    "is_committed['G5',6]"        1.91603e-09
# 295    "is_committed['G5',7]"        2.018e-09
# 296    "is_committed['G5',8]"        1.94379e-09
# 297    "is_committed['G5',9]"        1.90648e-09
# 298    "is_committed['G5',10]"       1.89414e-09
# 299    "is_committed['G5',11]"       1.90366e-09
# 300    "is_committed['G5',12]"       1.90313e-09
# 301    "is_committed['G5',13]"       1.89356e-09
# 302    "is_committed['G5',14]"       1.90431e-09
# 303    "is_committed['G5',15]"       1.90529e-09
# 304    "is_committed['G5',16]"       1.90554e-09
# 305    "is_committed['G5',17]"       1.90604e-09
# 306    "is_committed['G5',18]"       1.90662e-09
# 307    "is_committed['G5',19]"       1.90592e-09
# 308    "is_committed['G5',20]"       1.90552e-09
# 309    "is_committed['G5',21]"       1.90635e-09
# 310    "is_committed['G5',22]"       1.90814e-09
# 311    "is_committed['G5',23]"       1.9075e-09
# 312    "is_committed['G5',24]"       1.90664e-09
# 313    "is_committed['G5',25]"       1.90548e-09
# 314    "is_committed['G5',26]"       1.90524e-09
# 315    "is_committed['G5',27]"       1.90812e-09
# 316    "is_committed['G5',28]"       1.90649e-09
# 317    "is_committed['G5',29]"       1.90564e-09
# 318    "is_committed['G5',30]"       1.90501e-09
# 319    "is_committed['G5',31]"       1.90556e-09
# 320    "is_committed['G5',32]"       1.90722e-09
# 321    "is_committed['G5',33]"       1.90502e-09
# 322    "is_committed['G5',34]"       1.91023e-09
# 323    "is_committed['G5',35]"       1.90396e-09
# 324    "is_committed['G5',36]"       1.91124e-09
# 325    "is_committed['G5',37]"       1.90588e-09
# 326    "is_committed['G5',38]"       1.91055e-09
# 327    "is_committed['G5',39]"       1.91078e-09
# 328    "is_committed['G5',40]"       1.90383e-09
# 329    "is_committed['G5',41]"       1.90596e-09
# 330    "is_committed['G5',42]"       1.90559e-09
# 331    "is_committed['G5',43]"       1.90587e-09
# 332    "is_committed['G5',44]"       1.90683e-09
# 333    "is_committed['G5',45]"       1.90616e-09
# 334    "is_committed['G5',46]"       1.91056e-09
# 335    "is_committed['G5',47]"       1.90702e-09
# 336    "is_committed['G5',48]"       1.90663e-09
# 337    "is_committed['G5',49]"       1.90728e-09
# 338    "is_committed['G5',50]"       1.90839e-09
# 339    "is_committed['G5',51]"       1.90425e-09
# 340    "is_committed['G5',52]"       1.90566e-09
# 341    "is_committed['G5',53]"       1.90597e-09
# 342    "is_committed['G5',54]"       1.90625e-09
# 343    "is_committed['G5',55]"       1.90879e-09
# 344    "is_committed['G5',56]"       1.93596e-09
# 345    "is_committed['G5',57]"       1.90772e-09
# 346    "is_committed['G5',58]"       1.90842e-09
# 347    "is_committed['G5',59]"       1.9443e-09
# 348    "is_committed['G5',60]"       2.01209e-09
# 349    "is_committed['G5',61]"       1.91283e-09
# 350    "is_committed['G5',62]"       1.90549e-09
# 351    "is_committed['G5',63]"       1.90466e-09
# 352    "is_committed['G5',64]"       1.90483e-09
# 353    "is_committed['G5',65]"       1.9077e-09
# 354    "is_committed['G5',66]"       1.93565e-09
# 355    "is_committed['G5',67]"       1.90746e-09
# 356    "is_committed['G5',68]"       1.9059e-09
# 357    "is_committed['G5',69]"       1.9125e-09
# 358    "is_committed['G5',70]"       1.96627e-09
# 359    "is_committed['G5',71]"       1.99587e-09
# 360    "is_committed['G5',72]"       1.86147e-09
# 361    "is_committed['G6',1]"        1.42766e-09
# 362    "is_committed['G6',2]"        1.5046e-09
# 363    "is_committed['G6',3]"        1.55134e-09
# 364    "is_committed['G6',4]"        1.54882e-09
# 365    "is_committed['G6',5]"        1.53646e-09
# 366    "is_committed['G6',6]"        1.54496e-09
# 367    "is_committed['G6',7]"        1.53069e-09
# 368    "is_committed['G6',8]"        1.5049e-09
# 369    "is_committed['G6',9]"        1.52686e-09
# 370    "is_committed['G6',10]"       1.53611e-09
# 371    "is_committed['G6',11]"       1.50515e-09
# 372    "is_committed['G6',12]"       1.52694e-09
# 373    "is_committed['G6',13]"       1.53752e-09
# 374    "is_committed['G6',14]"       1.52867e-09
# 375    "is_committed['G6',15]"       1.52748e-09
# 376    "is_committed['G6',16]"       1.52604e-09
# 377    "is_committed['G6',17]"       1.50451e-09
# 378    "is_committed['G6',18]"       1.52514e-09
# 379    "is_committed['G6',19]"       1.50445e-09
# 380    "is_committed['G6',20]"       1.52654e-09
# 381    "is_committed['G6',21]"       1.52997e-09
# 382    "is_committed['G6',22]"       1.56481e-09
# 383    "is_committed['G6',23]"       1.53258e-09
# 384    "is_committed['G6',24]"       1.56532e-09
# 385    "is_committed['G6',25]"       1.54284e-09
# 386    "is_committed['G6',26]"       1.54465e-09
# 387    "is_committed['G6',27]"       1.50355e-09
# 388    "is_committed['G6',28]"       1.53747e-09
# 389    "is_committed['G6',29]"       1.52903e-09
# 390    "is_committed['G6',30]"       1.55389e-09
# 391    "is_committed['G6',31]"       1.50246e-09
# 392    "is_committed['G6',32]"       1.52393e-09
# 393    "is_committed['G6',33]"       1.50043e-09
# 394    "is_committed['G6',34]"       1.52103e-09
# 395    "is_committed['G6',35]"       1.50365e-09
# 396    "is_committed['G6',36]"       1.53238e-09
# 397    "is_committed['G6',37]"       1.50231e-09
# 398    "is_committed['G6',38]"       1.54123e-09
# 399    "is_committed['G6',39]"       1.53769e-09
# 400    "is_committed['G6',40]"       1.54008e-09
# 401    "is_committed['G6',41]"       1.54698e-09
# 402    "is_committed['G6',42]"       1.54905e-09
# 403    "is_committed['G6',43]"       1.52645e-09
# 404    "is_committed['G6',44]"       1.50396e-09
# 405    "is_committed['G6',45]"       1.52908e-09
# 406    "is_committed['G6',46]"       1.58844e-09
# 407    "is_committed['G6',47]"       1.52951e-09
# 408    "is_committed['G6',48]"       1.50212e-09
# 409    "is_committed['G6',49]"       1.5244e-09
# 410    "is_committed['G6',50]"       1.5026e-09
# 411    "is_committed['G6',51]"       1.50533e-09
# 412    "is_committed['G6',52]"       1.55258e-09
# 413    "is_committed['G6',53]"       1.54089e-09
# 414    "is_committed['G6',54]"       1.52849e-09
# 415    "is_committed['G6',55]"       1.52626e-09
# 416    "is_committed['G6',56]"       1.50558e-09
# 417    "is_committed['G6',57]"       1.53614e-09
# 418    "is_committed['G6',58]"       1.50134e-09
# 419    "is_committed['G6',59]"       1.50333e-09
# 420    "is_committed['G6',60]"       1.53178e-09
# 421    "is_committed['G6',61]"       1.52903e-09
# 422    "is_committed['G6',62]"       1.54197e-09
# 423    "is_committed['G6',63]"       1.56562e-09
# 424    "is_committed['G6',64]"       1.5308e-09
# 425    "is_committed['G6',65]"       1.52894e-09
# 426    "is_committed['G6',66]"       1.54734e-09
# 427    "is_committed['G6',67]"       1.60903e-09
# 428    "is_committed['G6',68]"       1.53888e-09
# 429    "is_committed['G6',69]"       1.5328e-09
# 430    "is_committed['G6',70]"       1.54873e-09
# 431    "is_committed['G6',71]"       1.61057e-09
# 432    "is_committed['G6',72]"       1.48569e-09
# 433    "is_committed['G7',1]"        1.3355e-09
# 434    "is_committed['G7',2]"        1.51987e-09
# 435    "is_committed['G7',3]"        1.53365e-09
# 436    "is_committed['G7',4]"        1.5341e-09
# 437    "is_committed['G7',5]"        1.53505e-09
# 438    "is_committed['G7',6]"        1.53456e-09
# 439    "is_committed['G7',7]"        1.53426e-09
# 440    "is_committed['G7',8]"        1.53434e-09
# 441    "is_committed['G7',9]"        1.53432e-09
# 442    "is_committed['G7',10]"       1.53462e-09
# 443    "is_committed['G7',11]"       1.53774e-09
# 444    "is_committed['G7',12]"       1.56685e-09
# 445    "is_committed['G7',13]"       1.53741e-09
# 446    "is_committed['G7',14]"       1.53503e-09
# 447    "is_committed['G7',15]"       1.5347e-09
# 448    "is_committed['G7',16]"       1.5345e-09
# 449    "is_committed['G7',17]"       1.53443e-09
# 450    "is_committed['G7',18]"       1.53455e-09
# 451    "is_committed['G7',19]"       1.53503e-09
# 452    "is_committed['G7',20]"       1.53511e-09
# 453    "is_committed['G7',21]"       1.53458e-09
# 454    "is_committed['G7',22]"       1.53515e-09
# 455    "is_committed['G7',23]"       1.53517e-09
# 456    "is_committed['G7',24]"       1.53283e-09
# 457    "is_committed['G7',25]"       1.53337e-09
# 458    "is_committed['G7',26]"       1.53327e-09
# 459    "is_committed['G7',27]"       1.53048e-09
# 460    "is_committed['G7',28]"       1.53151e-09
# 461    "is_committed['G7',29]"       1.53301e-09
# 462    "is_committed['G7',30]"       1.53429e-09
# 463    "is_committed['G7',31]"       1.54065e-09
# 464    "is_committed['G7',32]"       1.5313e-09
# 465    "is_committed['G7',33]"       1.54125e-09
# 466    "is_committed['G7',34]"       1.54243e-09
# 467    "is_committed['G7',35]"       1.53594e-09
# 468    "is_committed['G7',36]"       1.54271e-09
# 469    "is_committed['G7',37]"       1.54617e-09
# 470    "is_committed['G7',38]"       1.54335e-09
# 471    "is_committed['G7',39]"       1.54292e-09
# 472    "is_committed['G7',40]"       1.54121e-09
# 473    "is_committed['G7',41]"       1.53158e-09
# 474    "is_committed['G7',42]"       1.53259e-09
# 475    "is_committed['G7',43]"       1.53178e-09
# 476    "is_committed['G7',44]"       1.53057e-09
# 477    "is_committed['G7',45]"       1.5367e-09
# 478    "is_committed['G7',46]"       1.52922e-09
# 479    "is_committed['G7',47]"       1.53206e-09
# 480    "is_committed['G7',48]"       1.53372e-09
# 481    "is_committed['G7',49]"       1.53523e-09
# 482    "is_committed['G7',50]"       1.5331e-09
# 483    "is_committed['G7',51]"       1.53487e-09
# 484    "is_committed['G7',52]"       1.53499e-09
# 485    "is_committed['G7',53]"       1.53482e-09
# 486    "is_committed['G7',54]"       1.53443e-09
# 487    "is_committed['G7',55]"       1.53424e-09
# 488    "is_committed['G7',56]"       1.5342e-09
# 489    "is_committed['G7',57]"       1.53422e-09
# 490    "is_committed['G7',58]"       1.53417e-09
# 491    "is_committed['G7',59]"       1.53386e-09
# 492    "is_committed['G7',60]"       1.5341e-09
# 493    "is_committed['G7',61]"       1.53413e-09
# 494    "is_committed['G7',62]"       1.53423e-09
# 495    "is_committed['G7',63]"       1.53435e-09
# 496    "is_committed['G7',64]"       1.53434e-09
# 497    "is_committed['G7',65]"       1.53421e-09
# 498    "is_committed['G7',66]"       1.53414e-09
# 499    "is_committed['G7',67]"       1.53437e-09
# 500    "is_committed['G7',68]"       1.53414e-09
# 501    "is_committed['G7',69]"       1.53031e-09
# 502    "is_committed['G7',70]"       1.46768e-09
# 503    "is_committed['G7',71]"       1.44638e-09
# 504    "is_committed['G7',72]"       1.20161e-09
# 505    "power_generated['G1',1]"     1.13506e-07
# 506    "power_generated['G1',2]"     1.27245e-07
# 507    "power_generated['G1',3]"     1.38791e-07
# 508    "power_generated['G1',4]"     1.47205e-07
# 509    "power_generated['G1',5]"     1.42177e-07
# 510    "power_generated['G1',6]"     1.43333e-07
# 511    "power_generated['G1',7]"     1.48353e-07
# 512    "power_generated['G1',8]"     1.45963e-07
# 513    "power_generated['G1',9]"     1.42884e-07
# 514    "power_generated['G1',10]"    1.44863e-07
# 515    "power_generated['G1',11]"    1.42317e-07
# 516    "power_generated['G1',12]"    1.42415e-07
# 517    "power_generated['G1',13]"    1.45423e-07
# 518    "power_generated['G1',14]"    1.39399e-07
# 519    "power_generated['G1',15]"    1.41052e-07
# 520    "power_generated['G1',16]"    1.44637e-07
# 521    "power_generated['G1',17]"    1.401e-07
# 522    "power_generated['G1',18]"    1.45001e-07
# 523    "power_generated['G1',19]"    1.40291e-07
# 524    "power_generated['G1',20]"    1.39979e-07
# 525    "power_generated['G1',21]"    1.45354e-07
# 526    "power_generated['G1',22]"    1.37948e-07
# 527    "power_generated['G1',23]"    1.36855e-07
# 528    "power_generated['G1',24]"    1.34526e-07
# 529    "power_generated['G1',25]"    1.33266e-07
# 530    "power_generated['G1',26]"    1.32608e-07
# 531    "power_generated['G1',27]"    1.32217e-07
# 532    "power_generated['G1',28]"    1.32673e-07
# 533    "power_generated['G1',29]"    1.29588e-07
# 534    "power_generated['G1',30]"    1.29401e-07
# 535    "power_generated['G1',31]"    1.29145e-07
# 536    "power_generated['G1',32]"    1.33399e-07
# 537    "power_generated['G1',33]"    1.28955e-07
# 538    "power_generated['G1',34]"    1.30299e-07
# 539    "power_generated['G1',35]"    1.28901e-07
# 540    "power_generated['G1',36]"    1.30578e-07
# 541    "power_generated['G1',37]"    1.2948e-07
# 542    "power_generated['G1',38]"    1.30288e-07
# 543    "power_generated['G1',39]"    1.30336e-07
# 544    "power_generated['G1',40]"    1.28565e-07
# 545    "power_generated['G1',41]"    1.31536e-07
# 546    "power_generated['G1',42]"    1.29653e-07
# 547    "power_generated['G1',43]"    1.2982e-07
# 548    "power_generated['G1',44]"    1.31834e-07
# 549    "power_generated['G1',45]"    1.29418e-07
# 550    "power_generated['G1',46]"    1.34425e-07
# 551    "power_generated['G1',47]"    1.3368e-07
# 552    "power_generated['G1',48]"    1.35272e-07
# 553    "power_generated['G1',49]"    1.36204e-07
# 554    "power_generated['G1',50]"    1.352e-07
# 555    "power_generated['G1',51]"    1.28507e-07
# 556    "power_generated['G1',52]"    1.31521e-07
# 557    "power_generated['G1',53]"    1.35907e-07
# 558    "power_generated['G1',54]"    1.4161e-07
# 559    "power_generated['G1',55]"    1.44243e-07
# 560    "power_generated['G1',56]"    1.45657e-07
# 561    "power_generated['G1',57]"    1.40432e-07
# 562    "power_generated['G1',58]"    1.40379e-07
# 563    "power_generated['G1',59]"    1.45139e-07
# 564    "power_generated['G1',60]"    1.45133e-07
# 565    "power_generated['G1',61]"    1.40041e-07
# 566    "power_generated['G1',62]"    1.40004e-07
# 567    "power_generated['G1',63]"    1.40387e-07
# 568    "power_generated['G1',64]"    1.39764e-07
# 569    "power_generated['G1',65]"    1.43116e-07
# 570    "power_generated['G1',66]"    1.45516e-07
# 571    "power_generated['G1',67]"    1.41472e-07
# 572    "power_generated['G1',68]"    1.44429e-07
# 573    "power_generated['G1',69]"    1.47215e-07
# 574    "power_generated['G1',70]"    1.67706e-07
# 575    "power_generated['G1',71]"    1.79004e-07
# 576    "power_generated['G1',72]"    1.75371e-07
# 577    "power_generated['G2',1]"    40.6977
# 578    "power_generated['G2',2]"    40.2791
# 579    "power_generated['G2',3]"    45.7209
# 580    "power_generated['G2',4]"    51.5814
# 581    "power_generated['G2',5]"    46.1395
# 582    "power_generated['G2',6]"    47.814
# 583    "power_generated['G2',7]"    57.0233
# 584    "power_generated['G2',8]"    55.3488
# 585    "power_generated['G2',9]"    51.1628
# 586    "power_generated['G2',10]"   56.6047
# 587    "power_generated['G2',11]"   52.8372
# 588    "power_generated['G2',12]"   53.2558
# 589    "power_generated['G2',13]"   56.1861
# 590    "power_generated['G2',14]"   46.9768
# 591    "power_generated['G2',15]"   47.3954
# 592    "power_generated['G2',16]"   51.5814
# 593    "power_generated['G2',17]"   48.6512
# 594    "power_generated['G2',18]"   52.8372
# 595    "power_generated['G2',19]"   46.1395
# 596    "power_generated['G2',20]"   42.3721
# 597    "power_generated['G2',21]"   52.4186
# 598    "power_generated['G2',22]"   43.6279
# 599    "power_generated['G2',23]"   42.3721
# 600    "power_generated['G2',24]"   34
# 601    "power_generated['G2',25]"   35.6744
# 602    "power_generated['G2',26]"   36.093
# 603    "power_generated['G2',27]"   30
# 604    "power_generated['G2',28]"   33.1628
# 605    "power_generated['G2',29]"   30
# 606    "power_generated['G2',30]"   30
# 607    "power_generated['G2',31]"   30
# 608    "power_generated['G2',32]"   32.3256
# 609    "power_generated['G2',33]"   30
# 610    "power_generated['G2',34]"   30
# 611    "power_generated['G2',35]"   30
# 612    "power_generated['G2',36]"   30
# 613    "power_generated['G2',37]"   30
# 614    "power_generated['G2',38]"   30
# 615    "power_generated['G2',39]"   30
# 616    "power_generated['G2',40]"   30
# 617    "power_generated['G2',41]"   30
# 618    "power_generated['G2',42]"   30
# 619    "power_generated['G2',43]"   30
# 620    "power_generated['G2',44]"   30
# 621    "power_generated['G2',45]"   30
# 622    "power_generated['G2',46]"   30.6517
# 623    "power_generated['G2',47]"   33.5814
# 624    "power_generated['G2',48]"   42.3721
# 625    "power_generated['G2',49]"   41.5349
# 626    "power_generated['G2',50]"   34.8372
# 627    "power_generated['G2',51]"   45.7209
# 628    "power_generated['G2',52]"   44.8837
# 629    "power_generated['G2',53]"   45.3023
# 630    "power_generated['G2',54]"   52.4186
# 631    "power_generated['G2',55]"   55.7674
# 632    "power_generated['G2',56]"   56.6047
# 633    "power_generated['G2',57]"   50.3256
# 634    "power_generated['G2',58]"   53.2558
# 635    "power_generated['G2',59]"   56.6047
# 636    "power_generated['G2',60]"   59.5349
# 637    "power_generated['G2',61]"   53.2558
# 638    "power_generated['G2',62]"   54.093
# 639    "power_generated['G2',63]"   49.4884
# 640    "power_generated['G2',64]"   48.2326
# 641    "power_generated['G2',65]"   55.3488
# 642    "power_generated['G2',66]"   56.1861
# 643    "power_generated['G2',67]"   48.6512
# 644    "power_generated['G2',68]"   51.1628
# 645    "power_generated['G2',69]"   46.5581
# 646    "power_generated['G2',70]"    8.1135e-07
# 647    "power_generated['G2',71]"    6.20805e-07
# 648    "power_generated['G2',72]"    2.15171e-07
# 649    "power_generated['G3',1]"     1.11572e-07
# 650    "power_generated['G3',2]"     1.24756e-07
# 651    "power_generated['G3',3]"     1.33452e-07
# 652    "power_generated['G3',4]"     1.37052e-07
# 653    "power_generated['G3',5]"     1.39993e-07
# 654    "power_generated['G3',6]"     1.34022e-07
# 655    "power_generated['G3',7]"     1.41304e-07
# 656    "power_generated['G3',8]"     1.36561e-07
# 657    "power_generated['G3',9]"     1.33694e-07
# 658    "power_generated['G3',10]"    1.38303e-07
# 659    "power_generated['G3',11]"    1.37735e-07
# 660    "power_generated['G3',12]"    1.34347e-07
# 661    "power_generated['G3',13]"    1.36179e-07
# 662    "power_generated['G3',14]"    1.34091e-07
# 663    "power_generated['G3',15]"    1.36386e-07
# 664    "power_generated['G3',16]"    1.31718e-07
# 665    "power_generated['G3',17]"    1.33218e-07
# 666    "power_generated['G3',18]"    1.34831e-07
# 667    "power_generated['G3',19]"    1.35313e-07
# 668    "power_generated['G3',20]"    1.35368e-07
# 669    "power_generated['G3',21]"    1.37109e-07
# 670    "power_generated['G3',22]"    1.36395e-07
# 671    "power_generated['G3',23]"    1.34107e-07
# 672    "power_generated['G3',24]"    1.32409e-07
# 673    "power_generated['G3',25]"    1.31643e-07
# 674    "power_generated['G3',26]"    1.3119e-07
# 675    "power_generated['G3',27]"    1.3009e-07
# 676    "power_generated['G3',28]"    1.29952e-07
# 677    "power_generated['G3',29]"    1.27011e-07
# 678    "power_generated['G3',30]"    1.26781e-07
# 679    "power_generated['G3',31]"    1.26353e-07
# 680    "power_generated['G3',32]"    1.30212e-07
# 681    "power_generated['G3',33]"    1.26187e-07
# 682    "power_generated['G3',34]"    1.27175e-07
# 683    "power_generated['G3',35]"    1.26169e-07
# 684    "power_generated['G3',36]"    1.27337e-07
# 685    "power_generated['G3',37]"    1.26534e-07
# 686    "power_generated['G3',38]"    1.27103e-07
# 687    "power_generated['G3',39]"    1.27167e-07
# 688    "power_generated['G3',40]"    1.26007e-07
# 689    "power_generated['G3',41]"    1.2749e-07
# 690    "power_generated['G3',42]"    1.27133e-07
# 691    "power_generated['G3',43]"    1.27265e-07
# 692    "power_generated['G3',44]"    1.29525e-07
# 693    "power_generated['G3',45]"    1.26803e-07
# 694    "power_generated['G3',46]"    1.31507e-07
# 695    "power_generated['G3',47]"    1.31472e-07
# 696    "power_generated['G3',48]"    1.3413e-07
# 697    "power_generated['G3',49]"    1.35793e-07
# 698    "power_generated['G3',50]"    1.3297e-07
# 699    "power_generated['G3',51]"    1.33656e-07
# 700    "power_generated['G3',52]"    1.3265e-07
# 701    "power_generated['G3',53]"    1.30713e-07
# 702    "power_generated['G3',54]"    1.35204e-07
# 703    "power_generated['G3',55]"    1.35599e-07
# 704    "power_generated['G3',56]"    1.38535e-07
# 705    "power_generated['G3',57]"    1.32833e-07
# 706    "power_generated['G3',58]"    1.33574e-07
# 707    "power_generated['G3',59]"    1.30401e-07
# 708    "power_generated['G3',60]"    1.40947e-07
# 709    "power_generated['G3',61]"    1.30322e-07
# 710    "power_generated['G3',62]"    1.33852e-07
# 711    "power_generated['G3',63]"    1.32704e-07
# 712    "power_generated['G3',64]"    1.34079e-07
# 713    "power_generated['G3',65]"    1.35517e-07
# 714    "power_generated['G3',66]"    1.35735e-07
# 715    "power_generated['G3',67]"    1.37049e-07
# 716    "power_generated['G3',68]"    1.41581e-07
# 717    "power_generated['G3',69]"    1.47109e-07
# 718    "power_generated['G3',70]"    1.65604e-07
# 719    "power_generated['G3',71]"    1.73242e-07
# 720    "power_generated['G3',72]"    1.68211e-07
# 721    "power_generated['G4',1]"     6.95782e-08
# 722    "power_generated['G4',2]"     7.63513e-08
# 723    "power_generated['G4',3]"     8.06269e-08
# 724    "power_generated['G4',4]"     8.10911e-08
# 725    "power_generated['G4',5]"     7.93951e-08
# 726    "power_generated['G4',6]"     8.01039e-08
# 727    "power_generated['G4',7]"     8.00734e-08
# 728    "power_generated['G4',8]"     7.79172e-08
# 729    "power_generated['G4',9]"     7.66993e-08
# 730    "power_generated['G4',10]"    7.9245e-08
# 731    "power_generated['G4',11]"    7.667e-08
# 732    "power_generated['G4',12]"    7.6669e-08
# 733    "power_generated['G4',13]"    7.94625e-08
# 734    "power_generated['G4',14]"    7.84627e-08
# 735    "power_generated['G4',15]"    8.00863e-08
# 736    "power_generated['G4',16]"    8.01979e-08
# 737    "power_generated['G4',17]"    8.04901e-08
# 738    "power_generated['G4',18]"    8.07261e-08
# 739    "power_generated['G4',19]"    7.94981e-08
# 740    "power_generated['G4',20]"    7.94028e-08
# 741    "power_generated['G4',21]"    8.06784e-08
# 742    "power_generated['G4',22]"    7.97019e-08
# 743    "power_generated['G4',23]"    7.9695e-08
# 744    "power_generated['G4',24]"    7.93802e-08
# 745    "power_generated['G4',25]"    7.92553e-08
# 746    "power_generated['G4',26]"    7.92209e-08
# 747    "power_generated['G4',27]"    7.93177e-08
# 748    "power_generated['G4',28]"    7.93311e-08
# 749    "power_generated['G4',29]"    7.8834e-08
# 750    "power_generated['G4',30]"    7.87537e-08
# 751    "power_generated['G4',31]"    7.86167e-08
# 752    "power_generated['G4',32]"    7.9496e-08
# 753    "power_generated['G4',33]"    7.856e-08
# 754    "power_generated['G4',34]"    7.91225e-08
# 755    "power_generated['G4',35]"    7.858e-08
# 756    "power_generated['G4',36]"    7.92245e-08
# 757    "power_generated['G4',37]"    7.87612e-08
# 758    "power_generated['G4',38]"    7.91443e-08
# 759    "power_generated['G4',39]"    7.91676e-08
# 760    "power_generated['G4',40]"    7.84433e-08
# 761    "power_generated['G4',41]"    7.90118e-08
# 762    "power_generated['G4',42]"    7.8851e-08
# 763    "power_generated['G4',43]"    7.89156e-08
# 764    "power_generated['G4',44]"    7.91448e-08
# 765    "power_generated['G4',45]"    7.87609e-08
# 766    "power_generated['G4',46]"    7.9902e-08
# 767    "power_generated['G4',47]"    7.93912e-08
# 768    "power_generated['G4',48]"    7.95412e-08
# 769    "power_generated['G4',49]"    7.95914e-08
# 770    "power_generated['G4',50]"    7.95468e-08
# 771    "power_generated['G4',51]"    7.9611e-08
# 772    "power_generated['G4',52]"    7.95961e-08
# 773    "power_generated['G4',53]"    7.95033e-08
# 774    "power_generated['G4',54]"    8.02241e-08
# 775    "power_generated['G4',55]"    8.03162e-08
# 776    "power_generated['G4',56]"    8.13275e-08
# 777    "power_generated['G4',57]"    8.01722e-08
# 778    "power_generated['G4',58]"    8.02196e-08
# 779    "power_generated['G4',59]"    8.15351e-08
# 780    "power_generated['G4',60]"    8.31649e-08
# 781    "power_generated['G4',61]"    8.0211e-08
# 782    "power_generated['G4',62]"    8.00859e-08
# 783    "power_generated['G4',63]"    8.003e-08
# 784    "power_generated['G4',64]"    8.00385e-08
# 785    "power_generated['G4',65]"    8.0182e-08
# 786    "power_generated['G4',66]"    8.13103e-08
# 787    "power_generated['G4',67]"    8.02026e-08
# 788    "power_generated['G4',68]"    8.05337e-08
# 789    "power_generated['G4',69]"    8.09112e-08
# 790    "power_generated['G4',70]"    8.53822e-08
# 791    "power_generated['G4',71]"    8.87064e-08
# 792    "power_generated['G4',72]"    8.39906e-08
# 793    "power_generated['G5',1]"     5.91005e-08
# 794    "power_generated['G5',2]"     6.24182e-08
# 795    "power_generated['G5',3]"     6.46158e-08
# 796    "power_generated['G5',4]"     6.49575e-08
# 797    "power_generated['G5',5]"     6.47071e-08
# 798    "power_generated['G5',6]"     6.50479e-08
# 799    "power_generated['G5',7]"     6.02549e-08
# 800    "power_generated['G5',8]"     6.5829e-08
# 801    "power_generated['G5',9]"     6.45947e-08
# 802    "power_generated['G5',10]"    6.75254e-08
# 803    "power_generated['G5',11]"    6.45019e-08
# 804    "power_generated['G5',12]"    6.45235e-08
# 805    "power_generated['G5',13]"    6.75476e-08
# 806    "power_generated['G5',14]"    6.45001e-08
# 807    "power_generated['G5',15]"    6.45146e-08
# 808    "power_generated['G5',16]"    6.46343e-08
# 809    "power_generated['G5',17]"    6.46069e-08
# 810    "power_generated['G5',18]"    6.47037e-08
# 811    "power_generated['G5',19]"    6.45692e-08
# 812    "power_generated['G5',20]"    6.44997e-08
# 813    "power_generated['G5',21]"    6.47564e-08
# 814    "power_generated['G5',22]"    6.46919e-08
# 815    "power_generated['G5',23]"    6.46549e-08
# 816    "power_generated['G5',24]"    6.43959e-08
# 817    "power_generated['G5',25]"    6.43108e-08
# 818    "power_generated['G5',26]"    6.4296e-08
# 819    "power_generated['G5',27]"    6.4452e-08
# 820    "power_generated['G5',28]"    6.44295e-08
# 821    "power_generated['G5',29]"    6.41293e-08
# 822    "power_generated['G5',30]"    6.40794e-08
# 823    "power_generated['G5',31]"    6.39936e-08
# 824    "power_generated['G5',32]"    6.45662e-08
# 825    "power_generated['G5',33]"    6.39524e-08
# 826    "power_generated['G5',34]"    6.44252e-08
# 827    "power_generated['G5',35]"    6.39625e-08
# 828    "power_generated['G5',36]"    6.45079e-08
# 829    "power_generated['G5',37]"    6.4111e-08
# 830    "power_generated['G5',38]"    6.44475e-08
# 831    "power_generated['G5',39]"    6.44674e-08
# 832    "power_generated['G5',40]"    6.38609e-08
# 833    "power_generated['G5',41]"    6.42508e-08
# 834    "power_generated['G5',42]"    6.41417e-08
# 835    "power_generated['G5',43]"    6.41835e-08
# 836    "power_generated['G5',44]"    6.4343e-08
# 837    "power_generated['G5',45]"    6.40926e-08
# 838    "power_generated['G5',46]"    6.48664e-08
# 839    "power_generated['G5',47]"    6.44232e-08
# 840    "power_generated['G5',48]"    6.45115e-08
# 841    "power_generated['G5',49]"    6.45497e-08
# 842    "power_generated['G5',50]"    6.45221e-08
# 843    "power_generated['G5',51]"    6.4634e-08
# 844    "power_generated['G5',52]"    6.46265e-08
# 845    "power_generated['G5',53]"    6.45854e-08
# 846    "power_generated['G5',54]"    6.46211e-08
# 847    "power_generated['G5',55]"    6.46799e-08
# 848    "power_generated['G5',56]"    6.54901e-08
# 849    "power_generated['G5',57]"    6.45257e-08
# 850    "power_generated['G5',58]"    6.46112e-08
# 851    "power_generated['G5',59]"    6.59328e-08
# 852    "power_generated['G5',60]"    5.99882e-08
# 853    "power_generated['G5',61]"    6.47779e-08
# 854    "power_generated['G5',62]"    6.45552e-08
# 855    "power_generated['G5',63]"    6.44457e-08
# 856    "power_generated['G5',64]"    6.4424e-08
# 857    "power_generated['G5',65]"    6.46367e-08
# 858    "power_generated['G5',66]"    6.55154e-08
# 859    "power_generated['G5',67]"    6.45351e-08
# 860    "power_generated['G5',68]"    6.46086e-08
# 861    "power_generated['G5',69]"    6.46283e-08
# 862    "power_generated['G5',70]"    6.83519e-08
# 863    "power_generated['G5',71]"    7.04888e-08
# 864    "power_generated['G5',72]"    6.62455e-08
# 865    "power_generated['G6',1]"    65.6977
# 866    "power_generated['G6',2]"    66.2791
# 867    "power_generated['G6',3]"    58.7209
# 868    "power_generated['G6',4]"    50.5814
# 869    "power_generated['G6',5]"    58.1395
# 870    "power_generated['G6',6]"    55.814
# 871    "power_generated['G6',7]"    43.0233
# 872    "power_generated['G6',8]"    45.3488
# 873    "power_generated['G6',9]"    51.1628
# 874    "power_generated['G6',10]"   43.6047
# 875    "power_generated['G6',11]"   48.8372
# 876    "power_generated['G6',12]"   48.2558
# 877    "power_generated['G6',13]"   44.1861
# 878    "power_generated['G6',14]"   56.9767
# 879    "power_generated['G6',15]"   56.3954
# 880    "power_generated['G6',16]"   50.5814
# 881    "power_generated['G6',17]"   54.6512
# 882    "power_generated['G6',18]"   48.8372
# 883    "power_generated['G6',19]"   58.1395
# 884    "power_generated['G6',20]"   63.3721
# 885    "power_generated['G6',21]"   49.4186
# 886    "power_generated['G6',22]"   61.6279
# 887    "power_generated['G6',23]"   63.3721
# 888    "power_generated['G6',24]"   75
# 889    "power_generated['G6',25]"   72.6744
# 890    "power_generated['G6',26]"   72.093
# 891    "power_generated['G6',27]"   66
# 892    "power_generated['G6',28]"   73.8372
# 893    "power_generated['G6',29]"   62
# 894    "power_generated['G6',30]"   61
# 895    "power_generated['G6',31]"   54.4136
# 896    "power_generated['G6',32]"   72.6744
# 897    "power_generated['G6',33]"   54.4136
# 898    "power_generated['G6',34]"   45.5883
# 899    "power_generated['G6',35]"   59
# 900    "power_generated['G6',36]"   44.1177
# 901    "power_generated['G6',37]"   52.9415
# 902    "power_generated['G6',38]"   44.1177
# 903    "power_generated['G6',39]"   44.1177
# 904    "power_generated['G6',40]"   56.0159
# 905    "power_generated['G6',41]"   64
# 906    "power_generated['G6',42]"   62
# 907    "power_generated['G6',43]"   63
# 908    "power_generated['G6',44]"   65
# 909    "power_generated['G6',45]"   58.0003
# 910    "power_generated['G6',46]"   70.3483
# 911    "power_generated['G6',47]"   74.4186
# 912    "power_generated['G6',48]"   63.3721
# 913    "power_generated['G6',49]"   64.5349
# 914    "power_generated['G6',50]"   73.8372
# 915    "power_generated['G6',51]"   58.7209
# 916    "power_generated['G6',52]"   59.8837
# 917    "power_generated['G6',53]"   59.3023
# 918    "power_generated['G6',54]"   49.4186
# 919    "power_generated['G6',55]"   44.7674
# 920    "power_generated['G6',56]"   43.6047
# 921    "power_generated['G6',57]"   52.3256
# 922    "power_generated['G6',58]"   48.2558
# 923    "power_generated['G6',59]"   43.6047
# 924    "power_generated['G6',60]"   39.5349
# 925    "power_generated['G6',61]"   48.2558
# 926    "power_generated['G6',62]"   47.093
# 927    "power_generated['G6',63]"   53.4884
# 928    "power_generated['G6',64]"   55.2326
# 929    "power_generated['G6',65]"   45.3488
# 930    "power_generated['G6',66]"   44.1861
# 931    "power_generated['G6',67]"   54.6512
# 932    "power_generated['G6',68]"   51.1628
# 933    "power_generated['G6',69]"   57.5581
# 934    "power_generated['G6',70]"   26
# 935    "power_generated['G6',71]"   21
# 936    "power_generated['G6',72]"   15
# 937    "power_generated['G7',1]"     5.82712e-06
# 938    "power_generated['G7',2]"     6.04412e-06
# 939    "power_generated['G7',3]"     1.89525e-06
# 940    "power_generated['G7',4]"     1.56912e-06
# 941    "power_generated['G7',5]"     1.92195e-06
# 942    "power_generated['G7',6]"     1.79396e-06
# 943    "power_generated['G7',7]"     1.4354e-06
# 944    "power_generated['G7',8]"     1.47331e-06
# 945    "power_generated['G7',9]"     1.59664e-06
# 946    "power_generated['G7',10]"    1.43956e-06
# 947    "power_generated['G7',11]"    1.53129e-06
# 948    "power_generated['G7',12]"    1.53333e-06
# 949    "power_generated['G7',13]"    1.45548e-06
# 950    "power_generated['G7',14]"    1.84439e-06
# 951    "power_generated['G7',15]"    1.8269e-06
# 952    "power_generated['G7',16]"    1.63773e-06
# 953    "power_generated['G7',17]"    1.74029e-06
# 954    "power_generated['G7',18]"    1.58595e-06
# 955    "power_generated['G7',19]"    1.91577e-06
# 956    "power_generated['G7',20]"    2.20968e-06
# 957    "power_generated['G7',21]"    1.61464e-06
# 958    "power_generated['G7',22]"    2.10647e-06
# 959    "power_generated['G7',23]"    2.31039e-06
# 960    "power_generated['G7',24]"    2.03696e-06
# 961    "power_generated['G7',25]"    2.45762e-06
# 962    "power_generated['G7',26]"    2.76674e-06
# 963    "power_generated['G7',27]"    3.82812e-06
# 964    "power_generated['G7',28]"    2.44613e-06
# 965    "power_generated['G7',29]"    4.37609e-06
# 966    "power_generated['G7',30]"    5.69395e-06
# 967    "power_generated['G7',31]"    0.413594
# 968    "power_generated['G7',32]"    3.1539e-06
# 969    "power_generated['G7',33]"    0.413564
# 970    "power_generated['G7',34]"    3.58825
# 971    "power_generated['G7',35]"    1.52194e-05
# 972    "power_generated['G7',36]"    4.11766
# 973    "power_generated['G7',37]"    0.941517
# 974    "power_generated['G7',38]"    4.11767
# 975    "power_generated['G7',39]"    4.11767
# 976    "power_generated['G7',40]"    0.0159264
# 977    "power_generated['G7',41]"    3.69703e-06
# 978    "power_generated['G7',42]"    4.39254e-06
# 979    "power_generated['G7',43]"    3.8247e-06
# 980    "power_generated['G7',44]"    4.32535e-06
# 981    "power_generated['G7',45]"    0.000298482
# 982    "power_generated['G7',46]"    2.92035e-06
# 983    "power_generated['G7',47]"    2.16812e-06
# 984    "power_generated['G7',48]"    2.33313e-06
# 985    "power_generated['G7',49]"    2.38992e-06
# 986    "power_generated['G7',50]"    1.88602e-06
# 987    "power_generated['G7',51]"    2.01493e-06
# 988    "power_generated['G7',52]"    2.02181e-06
# 989    "power_generated['G7',53]"    1.97628e-06
# 990    "power_generated['G7',54]"    1.59199e-06
# 991    "power_generated['G7',55]"    1.4567e-06
# 992    "power_generated['G7',56]"    1.4333e-06
# 993    "power_generated['G7',57]"    1.64223e-06
# 994    "power_generated['G7',58]"    1.52895e-06
# 995    "power_generated['G7',59]"    1.40793e-06
# 996    "power_generated['G7',60]"    1.35404e-06
# 997    "power_generated['G7',61]"    1.50741e-06
# ...
# 647    "Min_Gen_If_On['G3',6]"             0
# 648    "Min_Gen_If_On['G3',7]"             0
# 649    "Min_Gen_If_On['G3',8]"             0
# 650    "Min_Gen_If_On['G3',9]"             0
# 651    "Min_Gen_If_On['G3',10]"            0
# 652    "Min_Gen_If_On['G3',11]"            0
# 653    "Min_Gen_If_On['G3',12]"            0
# 654    "Min_Gen_If_On['G3',13]"            0
# 655    "Min_Gen_If_On['G3',14]"            0
# 656    "Min_Gen_If_On['G3',15]"            0
# 657    "Min_Gen_If_On['G3',16]"            0
# 658    "Min_Gen_If_On['G3',17]"            0
# 659    "Min_Gen_If_On['G3',18]"            0
# 660    "Min_Gen_If_On['G3',19]"            0
# 661    "Min_Gen_If_On['G3',20]"            0
# 662    "Min_Gen_If_On['G3',21]"            0
# 663    "Min_Gen_If_On['G3',22]"            0
# 664    "Min_Gen_If_On['G3',23]"            0
# 665    "Min_Gen_If_On['G3',24]"            0
# 666    "Min_Gen_If_On['G3',25]"            0
# 667    "Min_Gen_If_On['G3',26]"            0
# 668    "Min_Gen_If_On['G3',27]"            0
# 669    "Min_Gen_If_On['G3',28]"            0
# 670    "Min_Gen_If_On['G3',29]"            0
# 671    "Min_Gen_If_On['G3',30]"            0
# 672    "Min_Gen_If_On['G3',31]"            0
# 673    "Min_Gen_If_On['G3',32]"            0
# 674    "Min_Gen_If_On['G3',33]"            0
# 675    "Min_Gen_If_On['G3',34]"            0
# 676    "Min_Gen_If_On['G3',35]"            0
# 677    "Min_Gen_If_On['G3',36]"            0
# 678    "Min_Gen_If_On['G3',37]"            0
# 679    "Min_Gen_If_On['G3',38]"            0
# 680    "Min_Gen_If_On['G3',39]"            0
# 681    "Min_Gen_If_On['G3',40]"            0
# 682    "Min_Gen_If_On['G3',41]"            0
# 683    "Min_Gen_If_On['G3',42]"            0
# 684    "Min_Gen_If_On['G3',43]"            0
# 685    "Min_Gen_If_On['G3',44]"            0
# 686    "Min_Gen_If_On['G3',45]"            0
# 687    "Min_Gen_If_On['G3',46]"            0
# 688    "Min_Gen_If_On['G3',47]"            0
# 689    "Min_Gen_If_On['G3',48]"            0
# 690    "Min_Gen_If_On['G3',49]"            0
# 691    "Min_Gen_If_On['G3',50]"            0
# 692    "Min_Gen_If_On['G3',51]"            0
# 693    "Min_Gen_If_On['G3',52]"            0
# 694    "Min_Gen_If_On['G3',53]"            0
# 695    "Min_Gen_If_On['G3',54]"            0
# 696    "Min_Gen_If_On['G3',55]"            0
# 697    "Min_Gen_If_On['G3',56]"            0
# 698    "Min_Gen_If_On['G3',57]"            0
# 699    "Min_Gen_If_On['G3',58]"            0
# 700    "Min_Gen_If_On['G3',59]"            0
# 701    "Min_Gen_If_On['G3',60]"            0
# 702    "Min_Gen_If_On['G3',61]"            0
# 703    "Min_Gen_If_On['G3',62]"            0
# 704    "Min_Gen_If_On['G3',63]"            0
# 705    "Min_Gen_If_On['G3',64]"            0
# 706    "Min_Gen_If_On['G3',65]"            0
# 707    "Min_Gen_If_On['G3',66]"            0
# 708    "Min_Gen_If_On['G3',67]"            0
# 709    "Min_Gen_If_On['G3',68]"            0
# 710    "Min_Gen_If_On['G3',69]"            0
# 711    "Min_Gen_If_On['G3',70]"            0
# 712    "Min_Gen_If_On['G3',71]"            0
# 713    "Min_Gen_If_On['G3',72]"            0
# 714    "Min_Gen_If_On['G4',1]"             0
# 715    "Min_Gen_If_On['G4',2]"             0
# 716    "Min_Gen_If_On['G4',3]"             0
# 717    "Min_Gen_If_On['G4',4]"             0
# 718    "Min_Gen_If_On['G4',5]"             0
# 719    "Min_Gen_If_On['G4',6]"             0
# 720    "Min_Gen_If_On['G4',7]"             0
# 721    "Min_Gen_If_On['G4',8]"             0
# 722    "Min_Gen_If_On['G4',9]"             0
# 723    "Min_Gen_If_On['G4',10]"            0
# 724    "Min_Gen_If_On['G4',11]"            0
# 725    "Min_Gen_If_On['G4',12]"            0
# 726    "Min_Gen_If_On['G4',13]"            0
# 727    "Min_Gen_If_On['G4',14]"            0
# 728    "Min_Gen_If_On['G4',15]"            0
# 729    "Min_Gen_If_On['G4',16]"            0
# 730    "Min_Gen_If_On['G4',17]"            0
# 731    "Min_Gen_If_On['G4',18]"            0
# 732    "Min_Gen_If_On['G4',19]"            0
# 733    "Min_Gen_If_On['G4',20]"            0
# 734    "Min_Gen_If_On['G4',21]"            0
# 735    "Min_Gen_If_On['G4',22]"            0
# 736    "Min_Gen_If_On['G4',23]"            0
# 737    "Min_Gen_If_On['G4',24]"            0
# 738    "Min_Gen_If_On['G4',25]"            0
# 739    "Min_Gen_If_On['G4',26]"            0
# 740    "Min_Gen_If_On['G4',27]"            0
# 741    "Min_Gen_If_On['G4',28]"            0
# 742    "Min_Gen_If_On['G4',29]"            0
# 743    "Min_Gen_If_On['G4',30]"            0
# 744    "Min_Gen_If_On['G4',31]"            0
# 745    "Min_Gen_If_On['G4',32]"            0
# 746    "Min_Gen_If_On['G4',33]"            0
# 747    "Min_Gen_If_On['G4',34]"            0
# 748    "Min_Gen_If_On['G4',35]"            0
# 749    "Min_Gen_If_On['G4',36]"            0
# 750    "Min_Gen_If_On['G4',37]"            0
# 751    "Min_Gen_If_On['G4',38]"            0
# 752    "Min_Gen_If_On['G4',39]"            0
# 753    "Min_Gen_If_On['G4',40]"            0
# 754    "Min_Gen_If_On['G4',41]"            0
# 755    "Min_Gen_If_On['G4',42]"            0
# 756    "Min_Gen_If_On['G4',43]"            0
# 757    "Min_Gen_If_On['G4',44]"            0
# 758    "Min_Gen_If_On['G4',45]"            0
# 759    "Min_Gen_If_On['G4',46]"            0
# 760    "Min_Gen_If_On['G4',47]"            0
# 761    "Min_Gen_If_On['G4',48]"            0
# 762    "Min_Gen_If_On['G4',49]"            0
# 763    "Min_Gen_If_On['G4',50]"            0
# 764    "Min_Gen_If_On['G4',51]"            0
# 765    "Min_Gen_If_On['G4',52]"            0
# 766    "Min_Gen_If_On['G4',53]"            0
# 767    "Min_Gen_If_On['G4',54]"            0
# 768    "Min_Gen_If_On['G4',55]"            0
# 769    "Min_Gen_If_On['G4',56]"            0
# 770    "Min_Gen_If_On['G4',57]"            0
# 771    "Min_Gen_If_On['G4',58]"            0
# 772    "Min_Gen_If_On['G4',59]"            0
# 773    "Min_Gen_If_On['G4',60]"            0
# 774    "Min_Gen_If_On['G4',61]"            0
# 775    "Min_Gen_If_On['G4',62]"            0
# 776    "Min_Gen_If_On['G4',63]"            0
# 777    "Min_Gen_If_On['G4',64]"            0
# 778    "Min_Gen_If_On['G4',65]"            0
# 779    "Min_Gen_If_On['G4',66]"            0
# 780    "Min_Gen_If_On['G4',67]"            0
# 781    "Min_Gen_If_On['G4',68]"            0
# 782    "Min_Gen_If_On['G4',69]"            0
# 783    "Min_Gen_If_On['G4',70]"            0
# 784    "Min_Gen_If_On['G4',71]"            0
# 785    "Min_Gen_If_On['G4',72]"            0
# 786    "Min_Gen_If_On['G5',1]"             0
# 787    "Min_Gen_If_On['G5',2]"             0
# 788    "Min_Gen_If_On['G5',3]"             0
# 789    "Min_Gen_If_On['G5',4]"             0
# 790    "Min_Gen_If_On['G5',5]"             0
# 791    "Min_Gen_If_On['G5',6]"             0
# 792    "Min_Gen_If_On['G5',7]"             0
# 793    "Min_Gen_If_On['G5',8]"             0
# 794    "Min_Gen_If_On['G5',9]"             0
# 795    "Min_Gen_If_On['G5',10]"            0
# 796    "Min_Gen_If_On['G5',11]"            0
# 797    "Min_Gen_If_On['G5',12]"            0
# 798    "Min_Gen_If_On['G5',13]"            0
# 799    "Min_Gen_If_On['G5',14]"            0
# 800    "Min_Gen_If_On['G5',15]"            0
# 801    "Min_Gen_If_On['G5',16]"            0
# 802    "Min_Gen_If_On['G5',17]"            0
# 803    "Min_Gen_If_On['G5',18]"            0
# 804    "Min_Gen_If_On['G5',19]"            0
# 805    "Min_Gen_If_On['G5',20]"            0
# 806    "Min_Gen_If_On['G5',21]"            0
# 807    "Min_Gen_If_On['G5',22]"            0
# 808    "Min_Gen_If_On['G5',23]"            0
# 809    "Min_Gen_If_On['G5',24]"            0
# 810    "Min_Gen_If_On['G5',25]"            0
# 811    "Min_Gen_If_On['G5',26]"            0
# 812    "Min_Gen_If_On['G5',27]"            0
# 813    "Min_Gen_If_On['G5',28]"            0
# 814    "Min_Gen_If_On['G5',29]"            0
# 815    "Min_Gen_If_On['G5',30]"            0
# 816    "Min_Gen_If_On['G5',31]"            0
# 817    "Min_Gen_If_On['G5',32]"            0
# 818    "Min_Gen_If_On['G5',33]"            0
# 819    "Min_Gen_If_On['G5',34]"            0
# 820    "Min_Gen_If_On['G5',35]"            0
# 821    "Min_Gen_If_On['G5',36]"            0
# 822    "Min_Gen_If_On['G5',37]"            0
# 823    "Min_Gen_If_On['G5',38]"            0
# 824    "Min_Gen_If_On['G5',39]"            0
# 825    "Min_Gen_If_On['G5',40]"            0
# 826    "Min_Gen_If_On['G5',41]"            0
# 827    "Min_Gen_If_On['G5',42]"            0
# 828    "Min_Gen_If_On['G5',43]"            0
# 829    "Min_Gen_If_On['G5',44]"            0
# 830    "Min_Gen_If_On['G5',45]"            0
# 831    "Min_Gen_If_On['G5',46]"            0
# 832    "Min_Gen_If_On['G5',47]"            0
# 833    "Min_Gen_If_On['G5',48]"            0
# 834    "Min_Gen_If_On['G5',49]"            0
# 835    "Min_Gen_If_On['G5',50]"            0
# 836    "Min_Gen_If_On['G5',51]"            0
# 837    "Min_Gen_If_On['G5',52]"            0
# 838    "Min_Gen_If_On['G5',53]"            0
# 839    "Min_Gen_If_On['G5',54]"            0
# 840    "Min_Gen_If_On['G5',55]"            0
# 841    "Min_Gen_If_On['G5',56]"            0
# 842    "Min_Gen_If_On['G5',57]"            0
# 843    "Min_Gen_If_On['G5',58]"            0
# 844    "Min_Gen_If_On['G5',59]"            0
# 845    "Min_Gen_If_On['G5',60]"            0
# 846    "Min_Gen_If_On['G5',61]"            0
# 847    "Min_Gen_If_On['G5',62]"            0
# 848    "Min_Gen_If_On['G5',63]"            0
# 849    "Min_Gen_If_On['G5',64]"            0
# 850    "Min_Gen_If_On['G5',65]"            0
# 851    "Min_Gen_If_On['G5',66]"            0
# 852    "Min_Gen_If_On['G5',67]"            0
# 853    "Min_Gen_If_On['G5',68]"            0
# 854    "Min_Gen_If_On['G5',69]"            0
# 855    "Min_Gen_If_On['G5',70]"            0
# 856    "Min_Gen_If_On['G5',71]"            0
# 857    "Min_Gen_If_On['G5',72]"            0
# 858    "Min_Gen_If_On['G6',1]"             1
# 859    "Min_Gen_If_On['G6',2]"             1
# 860    "Min_Gen_If_On['G6',3]"             1
# 861    "Min_Gen_If_On['G6',4]"             1
# 862    "Min_Gen_If_On['G6',5]"             1
# 863    "Min_Gen_If_On['G6',6]"             1
# 864    "Min_Gen_If_On['G6',7]"             1
# 865    "Min_Gen_If_On['G6',8]"             1
# 866    "Min_Gen_If_On['G6',9]"             1
# 867    "Min_Gen_If_On['G6',10]"            1
# 868    "Min_Gen_If_On['G6',11]"            1
# 869    "Min_Gen_If_On['G6',12]"            1
# 870    "Min_Gen_If_On['G6',13]"            1
# 871    "Min_Gen_If_On['G6',14]"            1
# 872    "Min_Gen_If_On['G6',15]"            1
# 873    "Min_Gen_If_On['G6',16]"            1
# 874    "Min_Gen_If_On['G6',17]"            1
# 875    "Min_Gen_If_On['G6',18]"            1
# 876    "Min_Gen_If_On['G6',19]"            1
# 877    "Min_Gen_If_On['G6',20]"            1
# 878    "Min_Gen_If_On['G6',21]"            1
# 879    "Min_Gen_If_On['G6',22]"            1
# 880    "Min_Gen_If_On['G6',23]"            1
# 881    "Min_Gen_If_On['G6',24]"            1
# 882    "Min_Gen_If_On['G6',25]"            1
# 883    "Min_Gen_If_On['G6',26]"            1
# 884    "Min_Gen_If_On['G6',27]"            1
# 885    "Min_Gen_If_On['G6',28]"            1
# 886    "Min_Gen_If_On['G6',29]"            1
# 887    "Min_Gen_If_On['G6',30]"            1
# 888    "Min_Gen_If_On['G6',31]"            1
# 889    "Min_Gen_If_On['G6',32]"            1
# 890    "Min_Gen_If_On['G6',33]"            1
# 891    "Min_Gen_If_On['G6',34]"            1
# 892    "Min_Gen_If_On['G6',35]"            1
# 893    "Min_Gen_If_On['G6',36]"            1
# 894    "Min_Gen_If_On['G6',37]"            1
# 895    "Min_Gen_If_On['G6',38]"            1
# 896    "Min_Gen_If_On['G6',39]"            1
# 897    "Min_Gen_If_On['G6',40]"            1
# 898    "Min_Gen_If_On['G6',41]"            1
# 899    "Min_Gen_If_On['G6',42]"            1
# 900    "Min_Gen_If_On['G6',43]"            1
# 901    "Min_Gen_If_On['G6',44]"            1
# 902    "Min_Gen_If_On['G6',45]"            1
# 903    "Min_Gen_If_On['G6',46]"            1
# 904    "Min_Gen_If_On['G6',47]"            1
# 905    "Min_Gen_If_On['G6',48]"            1
# 906    "Min_Gen_If_On['G6',49]"            1
# 907    "Min_Gen_If_On['G6',50]"            1
# 908    "Min_Gen_If_On['G6',51]"            1
# 909    "Min_Gen_If_On['G6',52]"            1
# 910    "Min_Gen_If_On['G6',53]"            1
# 911    "Min_Gen_If_On['G6',54]"            1
# 912    "Min_Gen_If_On['G6',55]"            1
# 913    "Min_Gen_If_On['G6',56]"            1
# 914    "Min_Gen_If_On['G6',57]"            1
# 915    "Min_Gen_If_On['G6',58]"            1
# 916    "Min_Gen_If_On['G6',59]"            1
# 917    "Min_Gen_If_On['G6',60]"            1
# 918    "Min_Gen_If_On['G6',61]"            1
# 919    "Min_Gen_If_On['G6',62]"            1
# 920    "Min_Gen_If_On['G6',63]"            1
# 921    "Min_Gen_If_On['G6',64]"            1
# 922    "Min_Gen_If_On['G6',65]"            1
# 923    "Min_Gen_If_On['G6',66]"            1
# 924    "Min_Gen_If_On['G6',67]"            1
# 925    "Min_Gen_If_On['G6',68]"            1
# 926    "Min_Gen_If_On['G6',69]"            1
# 927    "Min_Gen_If_On['G6',70]"            1
# 928    "Min_Gen_If_On['G6',71]"            1
# 929    "Min_Gen_If_On['G6',72]"            1
# 930    "Min_Gen_If_On['G7',1]"             1
# 931    "Min_Gen_If_On['G7',2]"             1
# 932    "Min_Gen_If_On['G7',3]"             1
# 933    "Min_Gen_If_On['G7',4]"             1
# 934    "Min_Gen_If_On['G7',5]"             1
# 935    "Min_Gen_If_On['G7',6]"             1
# 936    "Min_Gen_If_On['G7',7]"             1
# 937    "Min_Gen_If_On['G7',8]"             1
# 938    "Min_Gen_If_On['G7',9]"             1
# 939    "Min_Gen_If_On['G7',10]"            1
# 940    "Min_Gen_If_On['G7',11]"            1
# 941    "Min_Gen_If_On['G7',12]"            1
# 942    "Min_Gen_If_On['G7',13]"            1
# 943    "Min_Gen_If_On['G7',14]"            1
# 944    "Min_Gen_If_On['G7',15]"            1
# 945    "Min_Gen_If_On['G7',16]"            1
# 946    "Min_Gen_If_On['G7',17]"            1
# 947    "Min_Gen_If_On['G7',18]"            1
# 948    "Min_Gen_If_On['G7',19]"            1
# 949    "Min_Gen_If_On['G7',20]"            1
# 950    "Min_Gen_If_On['G7',21]"            1
# 951    "Min_Gen_If_On['G7',22]"            1
# 952    "Min_Gen_If_On['G7',23]"            1
# 953    "Min_Gen_If_On['G7',24]"            1
# 954    "Min_Gen_If_On['G7',25]"            1
# 955    "Min_Gen_If_On['G7',26]"            1
# 956    "Min_Gen_If_On['G7',27]"            1
# 957    "Min_Gen_If_On['G7',28]"            1
# 958    "Min_Gen_If_On['G7',29]"            1
# 959    "Min_Gen_If_On['G7',30]"            1
# 960    "Min_Gen_If_On['G7',31]"            1
# 961    "Min_Gen_If_On['G7',32]"            1
# 962    "Min_Gen_If_On['G7',33]"            1
# 963    "Min_Gen_If_On['G7',34]"            1
# 964    "Min_Gen_If_On['G7',35]"            1
# 965    "Min_Gen_If_On['G7',36]"            1
# 966    "Min_Gen_If_On['G7',37]"            1
# 967    "Min_Gen_If_On['G7',38]"            1
# 968    "Min_Gen_If_On['G7',39]"            1
# 969    "Min_Gen_If_On['G7',40]"            1
# 970    "Min_Gen_If_On['G7',41]"            1
# 971    "Min_Gen_If_On['G7',42]"            1
# 972    "Min_Gen_If_On['G7',43]"            1
# 973    "Min_Gen_If_On['G7',44]"            1
# 974    "Min_Gen_If_On['G7',45]"            1
# 975    "Min_Gen_If_On['G7',46]"            1
# 976    "Min_Gen_If_On['G7',47]"            1
# 977    "Min_Gen_If_On['G7',48]"            1
# 978    "Min_Gen_If_On['G7',49]"            1
# 979    "Min_Gen_If_On['G7',50]"            1
# 980    "Min_Gen_If_On['G7',51]"            1
# 981    "Min_Gen_If_On['G7',52]"            1
# 982    "Min_Gen_If_On['G7',53]"            1
# 983    "Min_Gen_If_On['G7',54]"            1
# 984    "Min_Gen_If_On['G7',55]"            1
# 985    "Min_Gen_If_On['G7',56]"            1
# 986    "Min_Gen_If_On['G7',57]"            1
# 987    "Min_Gen_If_On['G7',58]"            1
# 988    "Min_Gen_If_On['G7',59]"            1
# 989    "Min_Gen_If_On['G7',60]"            1
# 990    "Min_Gen_If_On['G7',61]"            1
# 991    "Min_Gen_If_On['G7',62]"            1
# 992    "Min_Gen_If_On['G7',63]"            1
# 993    "Min_Gen_If_On['G7',64]"            1
# 994    "Min_Gen_If_On['G7',65]"            1
# 995    "Min_Gen_If_On['G7',66]"            1
# 996    "Min_Gen_If_On['G7',67]"            1
# 997    "Min_Gen_If_On['G7',68]"            1
# 998    "Min_Gen_If_On['G7',69]"            1
# 999    "Min_Gen_If_On['G7',70]"            1
# 1000   "Min_Gen_If_On['G7',71]"            1
# 1001   "Min_Gen_If_On['G7',72]"            1
# ;

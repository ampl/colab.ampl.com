# %% [markdown]
# # Travelling Salesman Problem with subtour elimination
# [![tsp_simple_cuts_generic.ipynb](https://img.shields.io/badge/github-%23121011.svg?logo=github)](https://github.com/ampl/amplcolab/blob/master/authors/mapgccv/callbacks/tsp_simple_cuts_generic.ipynb) [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ampl/amplcolab/blob/master/authors/mapgccv/callbacks/tsp_simple_cuts_generic.ipynb) [![Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/ampl/amplcolab/blob/master/authors/mapgccv/callbacks/tsp_simple_cuts_generic.ipynb) [![Gradient](https://assets.paperspace.io/img/gradient-badge.svg)](https://console.paperspace.com/github/ampl/amplcolab/blob/master/authors/mapgccv/callbacks/tsp_simple_cuts_generic.ipynb) [![Open In SageMaker Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/ampl/amplcolab/blob/master/authors/mapgccv/callbacks/tsp_simple_cuts_generic.ipynb) [![Hits](https://h.ampl.com/https://github.com/ampl/amplcolab/blob/master/authors/mapgccv/callbacks/tsp_simple_cuts_generic.ipynb)](https://colab.ampl.com)
#
# Description: this example shows how to solve a TSP  by eliminating subtours using amplpy and ampls
#
# Tags: callbacks, tsp
#
# Notebook author: Christian Valente <<christian.valente@gmail.com>>
#
# Model author: N/A

# %%
import os
if not os.path.isdir('tsp_inputs'):
    os.system('git clone https://github.com/ampl/amplcolab.git')
    os.chdir('amplcolab/authors/mapgccv/callbacks')

# %% [markdown]
# ### Setup and cloud integration

# %%
# Install dependencies
# !pip install -q amplpy amplpy-gurobi amplpy-cplex
# !pip install -q tsplib95 matplotlib

# %%
# Google Colab & Kaggle integration
from amplpy import AMPL, tools
ampl = tools.ampl_notebook(
    modules=["coin"], # modules to install
    license_uuid="default", # license to use
    g=globals()) # instantiate AMPL object and register magics

# %% [markdown]
# ### Options

# %%
import os
#if os.path.isdir('ampls-api'):
#    os.chdir('ampls-api/python/examples/notebooks/')
USE_CALLBACKS = True
PLOTSUBTOURS = True
TSP_FILE = "./tsp_inputs/a280.tsp"

# %% [markdown]
# ### Imports

# %%
SOLVER = "gurobi"
SOLVER_OPTIONS = ['outlev=1']
# Import utilities
from amplpy import AMPL, DataFrame  # pip install amplpy
if SOLVER == "gurobi":
    import amplpy_gurobi as ampls   # pip install amplpy-gurobi
elif SOLVER == "cplex":
    import amplpy_cplex as ampls    # pip install amplpy-cplex
elif SOLVER == "xpress":
    import amplpy_xpress as ampls   # pip install amplpy-gurobi
import tsplib95 as tsp              # pip install tsplib95
import matplotlib.pyplot as plt     # pip install matplotlib
import matplotlib.colors as colors
from time import time
plt.rcParams['figure.dpi'] = 200

# %% [markdown]
# ### Define TSP model in AMPL
#
# We are using amplpy to define the subtour elimination constraint in AMPL and instantiating it appropriately and ampls to add cuts directly from the solver callback.

# %%
# %%ampl
# set NODES ordered;
# param hpos {NODES};
# param vpos {NODES};
#
# set PAIRS := {i in NODES, j in NODES: ord(i) < ord(j)};
#
# param distance {(i,j) in PAIRS}
#    := sqrt((hpos[j]-hpos[i])**2 + (vpos[j]-vpos[i])**2);
#
# var X {PAIRS} binary;
#
# minimize Tour_Length: sum {(i,j) in PAIRS} distance[i,j] * X[i,j];
#
# subject to Visit_All {i in NODES}:
#    sum {(i, j) in PAIRS} X[i,j] + sum {(j, i) in PAIRS} X[j,i] = 2;

# %% [markdown]
# Function to load TSP data files and return a dictionary of (nodeid : coordinate)

# %%
def getDictFromTspFile(tspFile):
    p = tsp.load(tspFile)
    if not p.is_depictable:
        print("Problem is not depictable!")

    # Amendments as we need the nodes lexographically ordered
    nnodes = len(list(p.get_nodes()))
    i = 0
    while nnodes>1:
        nnodes = nnodes/10
        i+=1
    formatString = f"{{:0{i}d}}"
    nodes = {formatString.format(value) : p.node_coords[index+1] for index, value in enumerate(p.get_nodes())}
    return nodes

# %% [markdown]
# Create AMPL object with amplpy and load model and data

# %%
# Get the model from the cell above
tsp_model = _ampl_cells[0]

# Load model in AMPL
ampl = AMPL()
ampl.eval(tsp_model)
ampl.option["solver"] = SOLVER
ampl.option[SOLVER + "_options"] = ' '.join(SOLVER_OPTIONS)

# Set problem data from tsp file
nodes = getDictFromTspFile(TSP_FILE)

# Pass them to AMPL using a dataframe
df = DataFrame(index=[('NODES')], columns=['hpos', 'vpos'])
df.setValues(nodes)
ampl.setData(df, "NODES")

# Set some globals that never change during the execution of the problem
NODES = set(nodes.keys())
CPOINTS = {node : complex(coordinate[0], coordinate[1]) for (node, coordinate) in nodes.items()}

# %% [markdown]
# Define some helpers functions to plot the tours

# %%
def plotTours(tours: list, points_coordinate: dict):
    # Plot all the tours in the list each with a different color
    colors = ['b', 'g', 'c', 'm', 'y', 'k']
    for i, tour in enumerate(tours):
        tourCoordinates = [points_coordinate[point.strip("'")] for point in tour]
        color = colors[i % len(colors)]
        plot_all(tourCoordinates, color = color)
    plt.show()

def plot_all(tour, alpha=1, color=None):
    # Plot the tour as blue lines between blue circles
    plotline(list(tour) + [tour[0]], alpha=alpha, color=color)
    plotline([tour[0]], 's', alpha=alpha, color=color)
    
def plotline(points, style='o-', alpha=1, color=None):
    "Plot a list of points (complex numbers) in the 2-D plane."
    X, Y = XY(points)
    if color:
        plt.plot(X, Y, style, alpha=alpha, color=color)
    else:
        plt.plot(X, Y, style, alpha=alpha)
    
def XY(points):
    "Given a list of points, return two lists: X coordinates, and Y coordinates."
    return [p.real for p in points], [p.imag for p in points]

# %% [markdown]
# Define some helper functions to help with the graphs (e.g. get the subtour given a set of arcs)

# %%
# Graphs helper routines
def trasverse(node, arcs: set, allnodes: set, subtour = None) -> list:
    # Trasverses all the arcs in the set arcs, starting from node
    # and returns the tour
    if not subtour:
        subtour = list()
    # Find arcs involving the current node
    myarcs = [(i,j) for (i,j) in arcs if node == i or node == j]
    if len(myarcs) == 0:
        return 
    # Append the current node to the current subtour
    subtour.append(node)

    # Use the first arc found
    myarc = myarcs[0]
    # Find destination (or origin) node
    destination = next(i for i in myarc if i != node)
    # Remove from arcs and nodes to visit
    arcs.remove(myarc)
    if node in allnodes:
        allnodes.remove(node)

    trasverse(destination, arcs, allnodes, subtour)
    return subtour


def findSubTours(arcs: set, allnodes: set):
    """Find all the subtours defined by a set of arcs and
       return them as a list of list
    """
    subtours = list()
    allnodes = allnodes.copy()
    while len(allnodes) > 0:
        l = trasverse(next(iter(allnodes)), arcs, allnodes)
        subtours.append(l)
    return subtours

# %% [markdown]
# AMPLPY implementation of sub-tours elimination

# %%
def amplSubTourElimination(ampl: AMPL):
    # Add the constraint and the needed parameters
    subToursAMPL = """param nSubtours >= 0 integer, default 0;
    set SUB {1..nSubtours} within NODES;

    subject to Subtour_Elimination {k in 1..nSubtours}:
    sum {i in SUB[k], j in NODES diff SUB[k]} 
    if (i, j) in PAIRS then X[i, j] else X[j, i] >= 2;"""
    ampl.eval(subToursAMPL)

    nSubtoursParam = ampl.getParameter("nSubtours")
    SubtoursSet = ampl.getSet("SUB")

    allsubtours = list()
    while True: # Repeat until the solution contains only one tour
        ampl.solve()
        # Get solution
        ARCS = ampl.getData("{(i,j) in PAIRS : X[i,j] > 0} X[i,j];")
        ARCS = set([(i, j) for (i, j, k)in ARCS.toList()])
        subtours = findSubTours(ARCS, NODES)
        # If we have only one tour, the solution is valid
        if len(subtours) <= 1:
            break
        print(f"Found {len(subtours)} subtours, plotting them and adding cuts")
        if PLOTSUBTOURS:
            plotTours(subtours, CPOINTS)
        # Else add the current tours to the list of subtours
        allsubtours.extend(subtours)
        # And add those to the constraints by assigning the values to
        # the parameter and the set
        nSubtoursParam.set(len(allsubtours))
        for (i, tour) in enumerate(allsubtours):
            SubtoursSet[i+1].setValues(tour)

# %% [markdown]
# ampls callbacks implementation of subtours elimination

# %%
# Callback class that actually add the cuts if subtours are found in a solution
class MyCallback(ampls.GenericCallback):
    def __init__(self): 
        # Constructor, simply sets the iteration number to 0
        super().__init__()
        self.iteration = 0 
    def run(self):
        try:
            # For each solution
            if self.getAMPLWhere() == ampls.Where.MIPSOL:
                self.iteration += 1
                print(f"\nIteration {self.iteration}: Finding subtours")
                sol = self.getSolutionVector()
                arcs = [xvars[i] for i, value in enumerate(sol) if value > 0]
                subTours = findSubTours(set(arcs), set(vertices))
                if len(subTours) ==1:
                    print("No subtours detected. Not adding any cut")
                    return 0
                print(f"Adding {len(subTours)} cuts")
                if PLOTSUBTOURS:
                    plotTours(subTours, CPOINTS)
                for subTour in subTours:
                    st1 = set(subTour)
                    nst1 = set(vertices) - st1
                    externalArcs = [(i, j) if i < j else (j, i) for i in st1 for j in nst1]
                    varsExternalArcs = [xinverse[i, j] for (i, j) in externalArcs]
                    coeffs = [1 for i in range(len(varsExternalArcs))]
                    if PLOTSUBTOURS:
                        print("Adding cut for subtour:", st1)
                    self.addLazyIndices(varsExternalArcs, coeffs, ampls.CutDirection.GE, 2)
                    if len(subTours) == 2:
                        return 0
                print("Continue solving")
            return 0
        except Exception as e:
            print('Error:', e)
            return 1

# %%
# Global variables to store entities needed by the callbacks
# that never change
xvars = None
xinverse = None
vertices = None
def solverSubTourElimination(ampl: AMPL, solver, solver_options):
    global xvars, xinverse, vertices
    # Export the model using ampls
    model = ampl.exportModel(solver, solver_options)
    model.enableLazyConstraints()

    # Get the global maps between solver vars and AMPL entities
    varMap = model.getVarMapFiltered("X")
    #print("varMap:", varMap)
    inverse = model.getVarMapInverse()
    xvars = {index: ampls.var2tuple(var)[1:] for var, index in varMap.items()}
    xinverse = {ampls.var2tuple(var)[1:]: index for index, var in inverse.items()}
    vertices = list(sorted(set([x[0] for x in xvars.values()] + [x[1] for x in xvars.values()])))

    # Assign the callback
    callback = MyCallback()
    model.setCallback(callback)
    print("Start optimization")
    # Start the optimization
    model.optimize()
    # Import the solution back to AMPL
    ampl.importSolution(model)

# %% [markdown]
# Script running the optimization

# %%
t0 = time()
if not USE_CALLBACKS:
    amplSubTourElimination(ampl)
else:
    solverSubTourElimination(ampl, SOLVER, SOLVER_OPTIONS)
# Out:
# Start optimization
#
# Iteration 1: Finding subtours
# Adding 5 cuts
# Adding cut for subtour: {'049', '248', '130', '274', '235', '103', '171', '217', '102', '184', '276', '082', '101', '262', '021', '165', '169', '030', '146', '125'}
# Adding cut for subtour: {'189', '210', '214', '014', '120', '178', '052', '083', '229', '107', '272', '243', '108', '064', '199', '265', '041', '018', '092', '032', '141', '195', '279', '093', '075', '008', '164', '080', '118', '149', '224', '269', '220', '114', '051', '126', '215', '078', '161', '115', '081', '193', '268', '059', '157', '209', '186', '191', '176', '242', '250', '033', '105', '094', '042', '011', '004', '128', '015', '267', '246', '223', '047', '099', '232', '010', '221', '203', '117', '158', '077', '230', '264', '100', '150', '162', '202', '234', '048', '065', '053', '034', '090', '104', '086', '233', '190', '225', '137', '027', '168', '231', '241', '247', '005', '054', '129', '156', '207', '142', '256', '112', '277', '187', '204', '073', '043', '002', '181', '245', '200', '261', '063', '153', '116', '255', '180', '227', '013', '136', '006', '216', '174', '119', '056', '205', '113', '069', '046', '017', '173', '155', '211', '123', '134', '085', '144', '159', '271', '133', '135', '257', '009', '206', '148', '091', '095'}
# Adding cut for subtour: {'127', '026', '061', '124', '058', '070', '240', '147', '194', '062', '031', '020', '154', '140', '037', '188', '172', '028', '196', '007', '222', '244', '278', '138', '270', '035', '237', '239', '072', '109', '218', '029', '160', '067', '089', '044', '182', '074', '088', '252', '012', '238', '071', '019', '023', '259', '001', '024', '106', '198', '097', '212', '167', '098', '266', '096', '087', '280', '111', '260', '079', '050', '036', '055', '263', '197', '175', '110', '201', '228', '045', '040', '076', '121', '226', '003', '249', '039', '038', '060', '273', '236', '192', '022', '131', '025', '066', '151', '219', '170', '275'}
# Adding cut for subtour: {'185', '068', '016', '139', '122', '152', '254', '213', '179', '057', '251', '208', '183', '132', '177', '084', '166', '143'}
# Adding cut for subtour: {'253', '258', '163', '145'}
# Continue solving
#
# Iteration 2: Finding subtours
# Adding 70 cuts
# Adding cut for subtour: {'049', '050', '231', '232'}
# Adding cut for subtour: {'067', '068', '214', '213'}
# Adding cut for subtour: {'128', '153', '154', '127'}
# Adding cut for subtour: {'026', '255', '025', '256'}
# Adding cut for subtour: {'013', '014', '267', '268'}
# Adding cut for subtour: {'124', '123', '157', '158'}
# Adding cut for subtour: {'074', '207', '208', '073'}
# Adding cut for subtour: {'184', '098', '183', '097'}
# Adding cut for subtour: {'070', '211', '212', '069'}
# Adding cut for subtour: {'084', '083', '198', '197'}
# Adding cut for subtour: {'051', '229', '230', '052'}
# Adding cut for subtour: {'104', '103', '178', '177'}
# Adding cut for subtour: {'148', '134', '133', '147'}
# Adding cut for subtour: {'180', '101', '102', '179'}
# Adding cut for subtour: {'116', '166', '165', '115'}
# Adding cut for subtour: {'037', '244', '038', '243'}
# Adding cut for subtour: {'063', '218', '217', '064'}
# Adding cut for subtour: {'266', '016', '265', '015'}
# Adding cut for subtour: {'150', '149', '132', '131'}
# Adding cut for subtour: {'041', '240', '239', '042'}
# Adding cut for subtour: {'263', '264', '018', '017'}
# Adding cut for subtour: {'196', '085', '195', '086'}
# Adding cut for subtour: {'279', '280', '001', '002'}
# Adding cut for subtour: {'109', '171', '110', '172'}
# Adding cut for subtour: {'075', '205', '206', '076'}
# Adding cut for subtour: {'274', '273', '007', '008'}
# Adding cut for subtour: {'027', '028', '253', '254'}
# Adding cut for subtour: {'151', '130', '129', '152'}
# Adding cut for subtour: {'034', '248', '033', '247'}
# Adding cut for subtour: {'164', '117', '118', '163'}
# Adding cut for subtour: {'080', '202', '201', '079'}
# Adding cut for subtour: {'168', '167', '114', '113'}
# Adding cut for subtour: {'144', '138', '143', '137'}
# Adding cut for subtour: {'035', '245', '036', '246'}
# Adding cut for subtour: {'203', '078', '077', '204'}
# Adding cut for subtour: {'216', '215', '065', '066'}
# Adding cut for subtour: {'088', '193', '087', '194'}
# Adding cut for subtour: {'072', '209', '210', '071'}
# Adding cut for subtour: {'030', '251', '029', '252'}
# Adding cut for subtour: {'122', '160', '159', '121'}
# Adding cut for subtour: {'241', '039', '242', '040'}
# Adding cut for subtour: {'094', '187', '093', '188'}
# Adding cut for subtour: {'105', '106', '176', '175'}
# Adding cut for subtour: {'146', '135', '136', '145'}
# Adding cut for subtour: {'011', '012', '270', '269'}
# Adding cut for subtour: {'238', '044', '237', '043'}
# Adding cut for subtour: {'258', '024', '023', '257'}
# Adding cut for subtour: {'100', '181', '182', '099'}
# Adding cut for subtour: {'010', '009', '272', '271'}
# Adding cut for subtour: {'262', '261', '019', '020'}
# Adding cut for subtour: {'162', '119', '161', '120'}
# Adding cut for subtour: {'259', '022', '021', '260'}
# Adding cut for subtour: {'048', '047', '233', '234'}
# Adding cut for subtour: {'185', '186', '095', '096'}
# Adding cut for subtour: {'228', '227', '053', '054'}
# Adding cut for subtour: {'189', '190', '092', '091'}
# Adding cut for subtour: {'112', '111', '169', '170'}
# Adding cut for subtour: {'126', '156', '125', '155'}
# Adding cut for subtour: {'003', '278', '004', '277'}
# Adding cut for subtour: {'199', '082', '200', '081'}
# Adding cut for subtour: {'226', '056', '055', '225'}
# Adding cut for subtour: {'235', '046', '045', '236'}
# Adding cut for subtour: {'031', '249', '250', '032'}
# Adding cut for subtour: {'060', '222', '221', '059'}
# Adding cut for subtour: {'089', '090', '191', '192'}
# Adding cut for subtour: {'220', '219', '062', '061'}
# Adding cut for subtour: {'223', '058', '057', '224'}
# Adding cut for subtour: {'107', '173', '108', '174'}
# Adding cut for subtour: {'141', '139', '142', '140'}
# Adding cut for subtour: {'276', '006', '005', '275'}
# Continue solving
#
# Iteration 3: Finding subtours
# Adding 18 cuts
# Adding cut for subtour: {'049', '051', '050', '052'}
# Adding cut for subtour: {'248', '210', '230', '214', '255', '224', '228', '222', '227', '220', '259', '226', '249', '216', '215', '229', '213', '212', '218', '209', '225', '253', '250', '260', '211', '256', '254', '252', '223', '258', '217', '257', '219', '251', '262', '261', '221', '263'}
# Adding cut for subtour: {'189', '127', '026', '014', '061', '124', '120', '070', '083', '178', '102', '107', '062', '165', '031', '108', '020', '064', '154', '199', '132', '041', '018', '140', '092', '032', '037', '068', '141', '188', '279', '075', '008', '028', '130', '164', '080', '118', '007', '149', '278', '269', '138', '270', '126', '035', '078', '161', '072', '081', '109', '157', '268', '029', '016', '160', '067', '186', '176', '122', '033', '105', '089', '042', '011', '004', '128', '030', '074', '088', '012', '015', '267', '071', '103', '099', '010', '101', '019', '158', '077', '023', '179', '169', '276', '162', '100', '150', '024', '106', '198', '065', '034', '090', '104', '167', '166', '266', '190', '139', '137', '027', '168', '111', '005', '129', '156', '177', '079', '112', '277', '187', '073', '043', '200', '036', '163', '021', '063', '153', '175', '110', '201', '180', '013', '040', '136', '145', '006', '121', '076', '003', '039', '174', '038', '119', '082', '060', '273', '069', '022', '173', '131', '017', '155', '123', '134', '025', '144', '159', '271', '133', '066', '274', '151', '152', '135', '009', '148', '091', '125', '275'}
# Adding cut for subtour: {'207', '264', '208'}
# Adding cut for subtour: {'185', '181', '272', '183', '182', '184'}
# Adding cut for subtour: {'146', '142', '143', '147'}
# Adding cut for subtour: {'247', '241', '242', '245', '244', '243', '240'}
# Adding cut for subtour: {'204', '265', '205', '206', '203', '202'}
# Adding cut for subtour: {'196', '195', '197', '194'}
# Adding cut for subtour: {'171', '170', '172'}
# Adding cut for subtour: {'116', '115', '113', '086', '084', '085', '114', '087', '117'}
# Adding cut for subtour: {'191', '193', '192'}
# Adding cut for subtour: {'097', '095', '094', '093', '098', '096'}
# Adding cut for subtour: {'238', '231', '237', '239', '232', '246'}
# Adding cut for subtour: {'235', '236', '233', '234'}
# Adding cut for subtour: {'001', '280', '002'}
# Adding cut for subtour: {'048', '046', '047', '053', '055', '054'}
# Adding cut for subtour: {'057', '044', '058', '045', '056', '059'}
# Continue solving
#
# Iteration 4: Finding subtours
# Adding 8 cuts
# Adding cut for subtour: {'147', '199', '143', '200', '142', '146', '144', '145'}
# Adding cut for subtour: {'175', '164', '120', '169', '162', '121', '171', '161', '102', '119', '165', '172', '167', '166', '157', '160', '168', '122', '123', '159', '163', '170', '158'}
# Adding cut for subtour: {'155', '156', '153', '154'}
# Adding cut for subtour: {'110', '094', '093', '090', '089', '109', '091', '108', '092'}
# Adding cut for subtour: {'105', '104', '103'}
# Adding cut for subtour: {'238', '231', '237', '235', '232', '236', '233', '234'}
# Adding cut for subtour: {'100', '101', '099'}
# Adding cut for subtour: {'116', '117', '086'}
# Adding cut for subtour: {'046', '055', '057', '044', '058', '056', '045', '059'}
# Adding cut for subtour: {'270', '134', '135', '269'}
# Adding cut for subtour: {'107', '173', '106', '174'}
# Adding cut for subtour: {'068', '069'}
# Adding cut for subtour: {'115'}
# Adding cut for subtour: {'067'}
# Adding cut for subtour: {'088'}
# Adding cut for subtour: {'095', '096', '097'}
# Adding cut for subtour: {'098'}
# Continue solving
#
# Iteration 6: Finding subtours
# Adding 18 cuts
# Adding cut for subtour: {'048', '049', '046', '051', '047', '053', '055', '057', '054', '050', '044', '045', '058', '056', '052', '059'}
# Adding cut for subtour: {'189', '210', '214', '127', '026', '014', '183', '240', '178', '194', '229', '213', '272', '243', '020', '154', '265', '254', '195', '188', '279', '217', '008', '248', '028', '130', '196', '007', '224', '222', '244', '278', '269', '220', '270', '126', '237', '215', '239', '218', '193', '268', '191', '029', '016', '186', '176', '235', '242', '250', '182', '011', '004', '128', '267', '246', '012', '238', '223', '015', '258', '232', '251', '010', '221', '184', '203', '230', '023', '179', '264', '276', '259', '150', '202', '234', '001', '185', '024', '198', '212', '266', '233', '280', '190', '225', '247', '231', '241', '137', '027', '005', '260', '129', '156', '207', '177', '256', '277', '187', '204', '002', '181', '245', '262', '261', '021', '263', '153', '197', '255', '201', '228', '180', '227', '013', '136', '006', '226', '003', '249', '216', '205', '273', '236', '192', '022', '131', '155', '211', '134', '025', '271', '274', '151', '152', '135', '257', '219', '009', '206', '275'}
# Adding cut for subtour: {'061', '118', '124', '040', '114', '035', '065', '039', '034', '038', '062', '113', '031', '060', '087', '064', '111', '033', '042', '030', '085', '041', '084', '112', '032', '037', '043', '066', '036', '063', '125'}
# Adding cut for subtour: {'252', '209', '208', '253'}
# Adding cut for subtour: {'077', '071', '073', '080', '078', '083', '074', '072', '081', '082', '079', '070', '075', '076'}
# Adding cut for subtour: {'141', '139', '147', '149', '142', '138', '148', '140'}
# Adding cut for subtour: {'175', '164', '120', '169', '162', '121', '106', '171', '161', '102', '174', '107', '104', '119', '165', '172', '167', '166', '157', '160', '168', '122', '173', '105', '123', '159', '103', '163', '170', '158'}
# Adding cut for subtour: {'133', '017', '132', '018', '019'}
# Adding cut for subtour: {'110', '094', '093', '090', '089', '109', '091', '108', '092'}
# Adding cut for subtour: {'199', '143', '200', '146', '144', '145'}
# Adding cut for subtour: {'100', '101', '099'}
# Adding cut for subtour: {'116', '117', '086'}
', '245', '036', '200', '163', '262', '261', '021', '263', '063', '153', '197', '175', '110', '116', '255', '201', '228', '180', '227', '045', '013', '040', '136', '145', '006', '076', '226', '003', '121', '249', '216', '039', '038', '174', '082', '119', '056', '205', '113', '060', '273', '236', '069', '192', '253', '131', '017', '022', '173', '155', '211', '123', '134', '025', '085', '144', '159', '271', '133', '066', '274', '151', '152', '135', '257', '057', '219', '009', '148', '206', '170', '091', '095', '125', '275'}
# Adding cut for subtour: {'046', '047', '055', '054'}
# Continue solving
#
# Iteration 13: Finding subtours
# No subtours detected. Not adding any cut
#
# Iteration 14: Finding subtours
# Adding 18 cuts
# Adding cut for subtour: {'048', '049', '046', '051', '047', '053', '055', '054', '050', '045', '056', '052'}
# Adding cut for subtour: {'214', '026', '014', '061', '208', '240', '229', '062', '272', '243', '031', '020', '265', '132', '254', '041', '018', '032', '037', '279', '217', '008', '248', '130', '028', '118', '007', '224', '222', '244', '278', '269', '220', '138', '270', '035', '237', '215', '239', '218', '268', '059', '209', '029', '016', '235', '242', '250', '033', '042', '011', '004', '252', '030', '267', '246', '012', '238', '223', '015', '258', '232', '251', '010', '221', '019', '230', '023', '264', '276', '259', '234', '001', '024', '034', '266', '233', '280', '225', '247', '231', '241', '137', '027', '005', '260', '256', '277', '043', '002', '245', '036', '262', '261', '021', '263', '063', '255', '228', '227', '013', '040', '136', '006', '226', '003', '249', '216', '039', '038', '060', '273', '236', '253', '131', '017', '022', '134', '025', '271', '133', '274', '135', '257', '219', '009', '275'}
# Adding cut for subtour: {'175', '127', '164', '124', '120', '169', '100', '162', '121', '126', '106', '097', '171', '161', '174', '102', '107', '090', '119', '104', '165', '172', '109', '167', '166', '098', '096', '157', '160', '168', '122', '173', '105', '094', '089', '123', '159', '092', '103', '099', '093', '163', '101', '170', '091', '095', '125', '158'}
# Adding cut for subtour: {'189', '210', '196', '201', '183', '202', '185', '198', '194', '213', '212', '205', '193', '191', '186', '190', '192', '199', '207', '211', '187', '204', '195', '188', '200', '206', '184', '203', '197'}
# Adding cut for subtour: {'077', '071', '067', '073', '080', '078', '083', '074', '072', '081', '082', '079', '070', '088', '075', '076'}
# Adding cut for subtour: {'176', '181', '179', '180', '182', '150', '178'}
# Adding cut for subtour: {'145', '141', '139', '147', '149', '142', '148', '146', '144', '140', '143'}
# Adding cut for subtour: {'066', '064', '065', '116', '115', '113', '084', '085', '114', '087', '117'}
# Adding cut for subtour: {'129', '128', '154'}
# Adding cut for subtour: {'086'}
# Adding cut for subtour: {'112', '111'}
# Adding cut for subtour: {'156', '153', '155'}
# Adding cut for subtour: {'110'}
# Adding cut for subtour: {'151', '177'}
# Adding cut for subtour: {'044', '058', '057'}
# Adding cut for subtour: {'108'}
# Adding cut for subtour: {'068', '069'}
# Adding cut for subtour: {'152'}
# Continue solving
#
# Iteration 15: Finding subtours
# Adding 2 cuts
', '053', '034', '090', '104', '212', '086', '266', '166', '167', '098', '096', '233', '087', '280', '190', '139', '247', '137', '027', '241', '231', '225', '005', '168', '111', '260', '054', '207', '156', '129', '142', '256', '177', '084', '112', '079', '050', '277', '187', '204', '073', '043', '002', '181', '245', '036', '200', '055', '163', '262', '261', '263', '063', '153', '197', '175', '110', '116', '255', '201', '228', '180', '045', '227', '013', '040', '136', '145', '006', '121', '003', '226', '076', '249', '216', '039', '038', '174', '119', '082', '056', '205', '113', '060', '273', '236', '069', '046', '192', '022', '017', '253', '173', '155', '211', '123', '134', '025', '085', '144', '159', '271', '133', '066', '274', '151', '152', '135', '257', '057', '219', '009', '206', '148', '170', '091', '095', '125', '275'}
#
# Iteration 24: Finding subtours
# No subtours detected. Not adding any cut
#
# Iteration 25: Finding subtours
# No subtours detected. Not adding any cut
# Gurobi 9.1.2: optimal solution; objective 2586.7696475631597
# 8212 simplex iterations
# No dual variables returned.

# %% [markdown]
# Get the solution, print it and display it

# %%
# Get the solution into ARCS
ARCS = ampl.getData("{(i,j) in PAIRS : X[i,j] > 0} X[i,j];")
ARCS = set([(i,j) for (i,j,k) in ARCS.toList()])

# Display it
tours = findSubTours(ARCS, NODES)
for st in tours:
    print(st)
plotTours(tours, CPOINTS)
# Out:
# ['049', '048', '047', '046', '045', '044', '059', '063', '062', '118', '061', '060', '043', '042', '041', '040', '039', '038', '037', '036', '035', '034', '033', '032', '031', '029', '028', '027', '026', '022', '025', '023', '024', '014', '015', '013', '012', '011', '010', '008', '009', '007', '006', '005', '004', '277', '276', '275', '274', '273', '272', '271', '016', '017', '018', '133', '134', '270', '269', '135', '136', '268', '267', '137', '138', '139', '149', '148', '147', '146', '145', '144', '143', '142', '141', '140', '266', '265', '264', '263', '262', '261', '260', '259', '258', '257', '254', '255', '256', '249', '248', '278', '279', '003', '280', '001', '002', '242', '243', '241', '240', '239', '238', '237', '236', '235', '234', '233', '232', '231', '246', '245', '244', '247', '250', '251', '230', '229', '228', '227', '226', '225', '224', '223', '222', '221', '220', '219', '218', '217', '216', '215', '214', '213', '212', '211', '210', '209', '252', '253', '208', '207', '206', '205', '204', '203', '202', '200', '199', '198', '201', '196', '195', '194', '197', '193', '192', '191', '190', '189', '188', '187', '186', '185', '184', '183', '182', '181', '176', '180', '179', '150', '178', '177', '151', '152', '156', '153', '155', '154', '129', '130', '131', '132', '019', '020', '021', '128', '127', '126', '030', '125', '124', '123', '122', '121', '120', '119', '157', '158', '159', '160', '175', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '107', '106', '105', '104', '103', '102', '101', '100', '099', '098', '097', '096', '095', '094', '093', '092', '091', '090', '089', '109', '108', '110', '111', '114', '115', '117', '116', '086', '085', '084', '087', '113', '112', '088', '083', '082', '081', '080', '079', '078', '077', '076', '075', '074', '073', '072', '071', '070', '069', '068', '067', '066', '065', '064', '058', '057', '056', '055', '054', '053', '052', '051', '050']

# %%
ampl.getValue('Tour_Length')
# Out:
# 2586.7696475631615

# %%
time()-t0 # seconds
# Out:
# 9.330340385437012
